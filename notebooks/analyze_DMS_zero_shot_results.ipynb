# %%
import pandas as pd
import numpy as np
from pathlib import Path
from typing import Dict, List, Tuple

import os
from pathlib import Path
import re
import json
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
import seaborn as sns
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## Utils

# %%
import hashlib

# Contract
# inputs: dict model_name -> path (folder containing per-assay CSVs or nested)
# outputs: DataFrame (rows=models, cols=assays), long-form DataFrame for plotting
# error modes: missing columns, empty CSVs, mismatched lengths handled gracefully

ASSAY_ID_COL_CANDIDATES = [
    'DMS_id', 'Assay', 'assay', 'assay_id'
]
TRUTH_COL_CANDIDATES = [
    'DMS_score', 'ground_truth', 'y', 'fitness', 'label'
]
# Model score column will be inferred per CSV based on presence of columns other than standard ones.

CSV_GLOB = r"**/*.csv"


def _infer_assay_id(df: pd.DataFrame, default_from_path: str) -> str:
    for c in ASSAY_ID_COL_CANDIDATES:
        if c in df.columns and pd.api.types.is_string_dtype(df[c]):
            vals = df[c].dropna().unique()
            if len(vals) == 1:
                return str(vals[0])
    # fallback to filename stem
    return default_from_path


def _find_truth_col(df: pd.DataFrame) -> str:
    for c in TRUTH_COL_CANDIDATES:
        if c in df.columns and np.issubdtype(df[c].dtype, np.number):
            return c
    # Also try "DMS_score_Binarized" seen in some exports
    for c in df.columns:
        if c.lower() in {"dms_score", "dms_score_binarized", "true", "target"} and np.issubdtype(df[c].dtype, np.number):
            return c
    raise ValueError("No numeric ground-truth column found in candidates.")


def _find_model_score_cols(df: pd.DataFrame) -> List[str]:
    # Heuristic: numeric columns that are not index-like and not truth
    numeric_cols = [c for c in df.columns if np.issubdtype(df[c].dtype, np.number)]
    truth = set([_find_truth_col(df)]) if any(c in df.columns for c in TRUTH_COL_CANDIDATES) else set()
    ignore = set(['position', 'pos', 'i', 'j', 'k']) | truth
    score_cols = [c for c in numeric_cols if c not in ignore]
    return score_cols


def iter_assay_csvs(root: Path) -> List[Path]:
    return sorted([
        p for p in root.glob(CSV_GLOB)
        if p.is_file() and "_analysis_cache" not in p.parts
    ])


# ---- Caching-enabled Spearman computation (mirrors proseqo notebook) ----

def compute_spearman_for_file(
    model_name: str, 
    csv_path: Path
) -> Dict[str, float] | None:
    try:
        df = pd.read_csv(csv_path)
    except Exception:
        return None
    if df.empty:
        return None
    try:
        truth_col = _find_truth_col(df)
    except Exception:
        return None
    assay_id = _infer_assay_id(df, default_from_path=csv_path.stem)
    score_cols = _find_model_score_cols(df)
    if not score_cols:
        return None
    chosen = None
    for c in score_cols:
        if model_name == c or model_name in c:
            chosen = c
            break
    if chosen is None:
        chosen = [c for c in score_cols if c != truth_col][-1] if len(score_cols) > 1 else score_cols[0]
    x = df[truth_col].astype(float)
    y = df[chosen].astype(float)
    if len(x) < 2:
        return None
    rho = spearmanr(x, y, nan_policy='omit').correlation
    if pd.isna(rho):
        return None
    return {"stem": csv_path.stem, "assay": str(assay_id), "spearman": float(rho)}


def compute_spearman_per_assay(model_name: str, model_root: Path) -> List[Tuple[str, float]]:
    # Backward-compatible full recompute
    results: List[Tuple[str, float]] = []
    for csv_path in iter_assay_csvs(model_root):
        rec = compute_spearman_for_file(model_name, csv_path)
        if rec is not None:
            results.append((rec["assay"], rec["spearman"]))
    return results


def _cache_dir(root: Path) -> Path:
    cd = root / "_analysis_cache"
    cd.mkdir(exist_ok=True, parents=True)
    return cd


def _cache_file_for_model(root: Path, model_name: str) -> Path:
    # safe filename
    safe = re.sub(r"[^A-Za-z0-9_.-]", "_", model_name)
    return _cache_dir(root) / f"spearman_{safe}.csv"


def load_cached_spearman_full(root: Path, model_name: str):
    f = _cache_file_for_model(root, model_name)
    if f.exists():
        try:
            cdf = pd.read_csv(f)
            if {'assay','spearman'}.issubset(set(cdf.columns)):
                cdf['assay'] = cdf['assay'].astype(str)
                if 'stem' in cdf.columns:
                    cdf['stem'] = cdf['stem'].astype(str)
                return cdf
        except Exception:
            return None
    return None


def save_cached_spearman_df(root: Path, model_name: str, cdf: pd.DataFrame) -> None:
    f = _cache_file_for_model(root, model_name)
    cols = ['stem','assay','spearman'] if 'stem' in cdf.columns else ['assay','spearman']
    cdf.loc[:, cols].to_csv(f, index=False)


def compute_spearman_for_file_ensemble(
    model_names: List[str],
    csv_paths: List[Path]
) -> Dict[str, float] | None:
    # Average the predicted scores for each model over each mutation
    first_df = None
    preds_list = []
    truth = None

    for model_name, csv_path in zip(model_names, csv_paths):
        try:
            df = pd.read_csv(csv_path)
        except Exception:
            return None
        if df.empty:
            return None

        # Determine truth from the first dataframe
        if first_df is None:
            try:
                truth_col = _find_truth_col(df)
            except Exception:
                return None
            first_df = df
            truth = df[truth_col].astype(float).to_numpy()

        # Pick predicted score column for this model
        score_cols = _find_model_score_cols(df)
        if not score_cols:
            return None
        chosen = None
        for c in score_cols:
            if model_name == c or model_name in c:
                chosen = c
                break
        if chosen is None:
            chosen = [c for c in score_cols if c != truth_col][-1] if len(score_cols) > 1 else score_cols[0]

        preds_list.append(df[chosen].astype(float).to_numpy())

    if truth is None or len(truth) < 2:
        return None

    # Average predictions across models using numpy
    preds = np.nanmean(np.stack(preds_list, axis=1), axis=1)
    rho = spearmanr(truth, preds, nan_policy='omit').correlation
    if pd.isna(rho):
        return None
    assay_id = _infer_assay_id(first_df, default_from_path=csv_paths[0].stem)
    return {"stem": csv_paths[0].stem, "assay": str(assay_id), "spearman": float(rho)}

def compute_ensemble_spearman_per_assay(
    model_names: List[str],
    model_roots: List[Path]
) -> List[Tuple[str, float]]:
    # Backward-compatible full recompute for ensemble
    results: List[Tuple[str, float]] = []
    # Assume all models have same assay CSVs
    assay_csvs = iter_assay_csvs(model_roots[0])
    for csv_path in assay_csvs:
        csv_paths = [root / csv_path.relative_to(model_roots[0]) for root in model_roots]
        rec = compute_spearman_for_file_ensemble(model_names, csv_paths)
        if rec is not None:
            results.append((rec["assay"], rec["spearman"]))
    return results

def evaluate_models(
    model_paths: Dict[str, str],
    public_benchmark: pd.DataFrame, 
    *, 
    recompute: bool = False, 
    cache_root: Path | None = None,
    ensembles_to_compute: Dict[str, List[str]] = {}
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Evaluate multiple models on the ProteinGym benchmark.
    Args:
        model_paths: Dict mapping model names to paths (or "precomputed" for public benchmark).
        public_benchmark: DataFrame of precomputed Spearman correlations (assays x models).
        recompute: If True, ignore caches and recompute all Spearman correlations.
        cache_root: Optional Path to use as root for caching (defaults to current working directory).
        ensembles_to_compute: Dict mapping ensemble model names to list of base model names to average scores and then compute Spearman.
        Returns:
            - wide_df: DataFrame with models as rows and assays as columns (Spearman correlations).
            - long_df: Long-form DataFrame with columns ['model', 'assay', 'spearman'] for plotting.
    """
    wide = {}
    long_rows = []
    base_root = cache_root if cache_root is not None else Path.cwd()
    for name, path in model_paths.items():
        if path == "precomputed":
            # Look for model name in public benchmark
            if name in public_benchmark.columns:
                for assay in public_benchmark.index:
                    rho = public_benchmark.loc[assay, name]
                    if not pd.isna(rho):
                        wide.setdefault(name, {})[assay] = rho
                        long_rows.append({"model": name, "assay": assay, "spearman": rho})
        else:
            # Trim accidental whitespace in provided paths
            root = Path(str(path).strip())
            if not root.exists():
                print(f"[evaluate_models] Skipping '{name}': path not found -> {root}")
                continue
            expected_stems = [p.stem for p in iter_assay_csvs(root)]
            cdf = None if recompute else load_cached_spearman_full(root, name)
            if cdf is None or cdf.empty:
                # No usable cache: compute all
                rows = []
                for csv_path in iter_assay_csvs(root):
                    rec = compute_spearman_for_file(name, csv_path)
                    if rec is not None:
                        rows.append(rec)
                cdf = pd.DataFrame(rows, columns=["stem","assay","spearman"]) if rows else pd.DataFrame(columns=["stem","assay","spearman"])
                save_cached_spearman_df(root, name, cdf)
            else:
                # Cache exists: verify completeness by file stem
                cached_stems = set(cdf["stem"].astype(str)) if "stem" in cdf.columns else set(cdf["assay"].astype(str))
                missing = [s for s in expected_stems if s not in cached_stems]
                if missing:
                    new_rows = []
                    for csv_path in iter_assay_csvs(root):
                        if csv_path.stem in missing:
                            rec = compute_spearman_for_file(name, csv_path)
                            if rec is not None:
                                new_rows.append(rec)
                    if new_rows:
                        new_df = pd.DataFrame(new_rows)
                        if "stem" not in cdf.columns:
                            cdf["stem"] = cdf["assay"]
                        cdf = pd.concat([cdf, new_df], ignore_index=True)
                        cdf = cdf.drop_duplicates(subset=["stem"], keep="first")
                        save_cached_spearman_df(root, name, cdf)
            # Fill outputs from cache (complete or completed)
            pairs = [(str(a), float(r)) for a, r in zip(cdf["assay"], cdf["spearman"]) ]
            wide[name] = {assay: rho for assay, rho in pairs}
            for assay, rho in pairs:
                long_rows.append({"model": name, "assay": assay, "spearman": rho})
    # Handle ensembles
    for ensemble_name, base_models in ensembles_to_compute.items():
        name = "ensemble_" + hashlib.sha256("||".join(sorted(base_models)).encode("utf-8")).hexdigest()[:16]  # Unique name for caching
        expected_stems = [p.stem for p in iter_assay_csvs(base_root / model_paths[base_models[0]])]
        cdf = None if recompute else load_cached_spearman_full(base_root, name)
        if cdf is None or cdf.empty:
            print('(Re)computing ensemble:', ensemble_name, 'hashing name:', name)
            # No usable cache: compute all
            rows = compute_ensemble_spearman_per_assay(
                model_names=base_models,
                model_roots=[Path(str(model_paths[m]).strip()) for m in base_models if m in model_paths and model_paths[m] != "precomputed"]
            )
            cdf = pd.DataFrame(rows, columns=["assay","spearman"]) if rows else pd.DataFrame(columns=["assay","spearman"])
            save_cached_spearman_df(base_root, name, cdf)
        else:
            # Cache exists: verify completeness by file stem
            cached_stems = set(cdf["stem"].astype(str)) if "stem" in cdf.columns else set(cdf["assay"].astype(str))
            missing = [s for s in expected_stems if s not in cached_stems]
            if missing:
                new_rows = []
                for csv_path in iter_assay_csvs(base_root):
                    if csv_path.stem in missing:
                        rec = compute_spearman_for_file(name, csv_path)
                        if rec is not None:
                            new_rows.append(rec)
                if new_rows:
                    new_df = pd.DataFrame(new_rows)
                    if "stem" not in cdf.columns:
                        cdf["stem"] = cdf["assay"]
                    cdf = pd.concat([cdf, new_df], ignore_index=True)
                    cdf = cdf.drop_duplicates(subset=["stem"], keep="first")
                    save_cached_spearman_df(base_root, name, cdf)
        # Fill outputs from cache (complete or completed)
        pairs = [(str(a), float(r)) for a, r in zip(cdf["assay"], cdf["spearman"]) ]
        wide[ensemble_name] = {assay: rho for assay, rho in pairs}
        for assay, rho in pairs:
            long_rows.append({"model": ensemble_name, "assay": assay, "spearman": rho})
            
    wide_df = pd.DataFrame(wide).T.sort_index()
    long_df = pd.DataFrame(long_rows)
    return wide_df, long_df

# %%
# Display settings
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
plt.rcParams['figure.dpi'] = 120
sns.set_theme(style='whitegrid')

# %% [markdown]
# # Analyze ProteinGym DMS zero-shot results
# This notebook loads per-assay CSVs from one or more model result folders, computes Spearman correlations against ground truth for each assay, aggregates into a models×assays table, and visualizes distributions with a violin plot.

# %%
# Define your models here: { name: folder_with_csvs }
# Example:
# model_paths = {
#     "AMPLIFY-large": "/path/to/outputs/AMPLIFY-large",
#     "AnotherModel": "/path/to/outputs/AnotherModel"
# }
model_paths = {
    "AMPLIFY_350M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY/350M_hf_mm",
    "AMPLIFY_120M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY/120M_hf_mm",
    "AMPLIFY_120M_base": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY/120Mbase_hf_mm",
    "AMPLIFY_350M_base": "/home/mila/d/david.heurtel-depeiges/scratch/proteingym/results/zero_shot_substitutions_scores/AMPLIFY/350Mbase_hf_mm",
    "AMPLIFY_120M_UR50": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY/120M_UR50",
    "AMPLIFY_C": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY_2/350M_consensus_extended/",
    "AMPLIFY_C_base": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/AMPLIFY_2/350M_consensus/",
    "ESM2 (8M)": "precomputed",
    "ESM2 (35M)": "precomputed",
    "ESM2 (150M)" : "precomputed",
    "ESM2 (650M)" : "precomputed",
    "ESM2 (3B)" : "precomputed",
    "ESM2 (15B)" : "precomputed",
    # "myESM2_8M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/ESM2/8M_hf_mm",
    "SaESM2_650M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaESM2/650M_hf_mm",
    "SaESM2_150M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaESM2/150M_local_mm",
    "SaESM2_35M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaESM2/35M_local_mm",
    "SaESM2_8M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaESM2/8M_local_mm",
    "SaAMPLIFY_350M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaAMPLIFY/350M_hf_mm",
    "SaAMPLIFY_120M": "/network/scratch/d/david.heurtel-depeiges/proteingym/results/zero_shot_substitutions_scores/SaAMPLIFY/120M_hf_mm",
    # Add more models as needed
    'ESM3 open (1.4B)' : "precomputed",
    'ESM-C (300M)': "precomputed",
    'ESM-C (600M)': "precomputed",
}

# colors = {
#     "AMPLIFY_350M": "#064877",  # blue
#     "AMPLIFY_120M": "#2c6782",  # lighter blue
#     "SaAMPLIFY_350M": "#7e26cf",    # light purple
#     "SaAMPLIFY_120M": "#b160e7",    # lighter purple
#     "AMPLIFY_120M_UR50": "#7F91AA",  # blue green
#     "AMPLIFY_120M_base": "#515151",  # light gray
#     "AMPLIFY_350M_base": "#292929",  # dark grey
#     "ESM2 (8M)": "#ffcc80",      # light orange
#     "ESM2 (35M)": "#ff9f40",     # medium-light orange  
#     "ESM2 (150M)": "#ff8f00",    # medium orange
#     "ESM2 (650M)": "#ff6f00",    # medium-dark orange
#     "ESM2 (3B)": "#e65100",      # dark orange
#     "ESM2 (15B)": "#bf360c",     # very dark orange
#     # "myESM2_8M": "#7efa5f",      # light green 
#     "SaESM2_650M": "#1b5e20",     # deep forest/olive green (darkest, heaviest)
#     "SaESM2_150M": "#2e7d32",     # dark green-olive
#     "SaESM2_35M":  "#43a047",     # medium emerald green
#     "SaESM2_8M":   "#66c2a5",     # teal-green, darker than before
#     # Add more colors as needed
#     'ESM3 open (1.4B)' : "#fa1898",  # pink
#     'ESM-C (300M)': "#f56b8d",  # pink
#     'ESM-C (600M)': "#ff3392",  # pink
#     # Ensemble models
#     "AMPLIFY_ensemble": "#FFFB00",  # black
#     "SaAMPLIFY_ensemble": "#7A791C",  # dark gray
#     "SaESM2_ensemble": "#4D9C2D",  # medium gray
#     "Sa*_ensemble": "#4E6146",  # light gray
# }

colors = {
    "AMPLIFY_350M": "#5AA2FF",  # blue 
    "AMPLIFY_120M": "#9CC9FF",  # lighter blue
    "SaAMPLIFY_350M": "#008C7A",    # light purple
    "SaAMPLIFY_120M": "#39C7B9",    # lighter purple
    "AMPLIFY_120M_UR50": "#7F91AA",  # blue green
    "AMPLIFY_120M_base": "#515151",  # light gray
    "AMPLIFY_350M_base": "#292929",  # dark grey
    "AMPLIFY_C": "#004D40",  # teal
    "AMPLIFY_C_base": "#00332E",  # dark teal
    "ESM2 (8M)": "#F5CFAF",      # light orange
    "ESM2 (35M)": "#EBAA71",     # medium-light orange  
    "ESM2 (150M)": "#DA8B54",    # medium orange
    "ESM2 (650M)": "#CC7130",    # medium-dark orange
    "ESM2 (3B)": "#AC5B10",      # dark orange
    "ESM2 (15B)": "#7E3F05",     # very dark orange
    # "myESM2_8M": "#7efa5f",      # light green 
    "SaESM2_650M": "#C49B00",     # deep forest/olive green (darkest, heaviest)
    "SaESM2_150M": "#C49B00",     # dark green-olive
    "SaESM2_35M":  "#F4C532",     # medium emerald green
    "SaESM2_8M":   "#FFE37D",     # teal-green, darker than before
    # Add more colors as needed
    'ESM3 open (1.4B)' : "#A87EFF",  # pink
    'ESM-C (300M)': "#F04D9B",  # pink
    'ESM-C (600M)': "#B01A69",  # pink
    # Ensemble models
    "AMPLIFY_ensemble": "#FFFB00",  # black
    "SaAMPLIFY_ensemble": "#7A791C",  # dark gray
    "SaESM2_ensemble": "#4D9C2D",  # medium gray
    "Sa*_ensemble": "#4E6146",  # light gray
    "Thematic_ensemble": "#51814E",  # orange-red
}

model_sizes = { # In Millions of parameters
    "AMPLIFY_350M": 350,
    "AMPLIFY_120M": 120,
    "AMPLIFY_120M_base": 120,
    "AMPLIFY_350M_base": 350,
    "AMPLIFY_120M_UR50": 120,
    "AMPLIFY_C": 350,
    "AMPLIFY_C_base": 350,
    "ESM2 (8M)": 8,
    "ESM2 (35M)": 35,
    "ESM2 (150M)" : 150,
    "ESM2 (650M)" : 650,
    "ESM2 (3B)" : 3000,
    "ESM2 (15B)" : 15000,
    # "myESM2_8M": 8
    # Add more model sizes as needed
    "SaESM2_650M": 650,
    "SaESM2_150M": 150,
    "SaESM2_35M": 35,
    "SaESM2_8M": 8,
    "SaAMPLIFY_350M": 350,
    "SaAMPLIFY_120M": 120,
    'ESM3 open (1.4B)' : 1400,
    'ESM-C (300M)': 300,
    'ESM-C (600M)': 600,
}

model_families = {
    "AMPLIFY": ["AMPLIFY_350M", "AMPLIFY_120M"],
    "AMPLIFY_base": ["AMPLIFY_120M_base", "AMPLIFY_350M_base"],
    "AMPLIFY_C": ["AMPLIFY_C"],
    "AMPLIFY_C_base": ["AMPLIFY_C_base"],
    "SaAMPLIFY": ["SaAMPLIFY_350M", "SaAMPLIFY_120M"],
    "ESM2": [ "ESM2 (8M)", "ESM2 (35M)", "ESM2 (150M)", "ESM2 (650M)", "ESM2 (3B)", "ESM2 (15B)"],
    # "myESM2": ["myESM2_8M"],
    "SaESM2": ["SaESM2_650M", "SaESM2_150M", "SaESM2_35M", "SaESM2_8M"],
    "ESM-C": ["ESM-C (300M)", "ESM-C (600M)"],
    "ESM3": ["ESM3 open (1.4B)"],
    # Add more model families as needed
    "AMPLIFY_UR50": ["AMPLIFY_120M_UR50"],
}

# %%
# Load the previous results (all other public models)
repo_root = Path.cwd().parent
dms_substitutions_df = pd.read_csv(repo_root / "benchmarks/DMS_zero_shot/substitutions/Spearman/DMS_substitutions_Spearman_DMS_level.csv", index_col=0)

# %%
dms_substitutions_df.head() # Structure is index is DMS id, columsn are model names
# Out:
#                                   Site-Independent  EVmutation  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019              0.383       0.354
# A0A192B1T2_9HIV1_Haddox_2018                 0.481       0.407
# A0A1I9GEU1_NEIME_Kennouche_2019             -0.011       0.044
# A0A247D711_LISMN_Stadelmann_2021             0.436       0.459
# A0A2Z5U3Z0_9INFA_Doud_2016                   0.478       0.473
#
#                                   DeepSequence (single)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.131
# A0A192B1T2_9HIV1_Haddox_2018                      0.413
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.107
# A0A247D711_LISMN_Stadelmann_2021                  0.109
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.484
#
#                                   DeepSequence (ensemble)  EVE (single)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                     0.103         0.394
# A0A192B1T2_9HIV1_Haddox_2018                        0.432         0.509
# A0A1I9GEU1_NEIME_Kennouche_2019                     0.098         0.053
# A0A247D711_LISMN_Stadelmann_2021                    0.041         0.428
# A0A2Z5U3Z0_9INFA_Doud_2016                          0.517         0.545
#
#                                   EVE (ensemble)  Unirep  Unirep evotuned  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019            0.405  -0.133            0.062
# A0A192B1T2_9HIV1_Haddox_2018               0.516   0.000            0.513
# A0A1I9GEU1_NEIME_Kennouche_2019            0.054  -0.024            0.084
# A0A247D711_LISMN_Stadelmann_2021           0.428   0.003            0.026
# A0A2Z5U3Z0_9INFA_Doud_2016                 0.548   0.009            0.492
#
#                                   MSA Transformer (single)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                      0.436
# A0A192B1T2_9HIV1_Haddox_2018                         0.511
# A0A1I9GEU1_NEIME_Kennouche_2019                      0.082
# A0A247D711_LISMN_Stadelmann_2021                     0.299
# A0A2Z5U3Z0_9INFA_Doud_2016                           0.495
#
#                                   MSA Transformer (ensemble)  ESM-1b  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                        0.439  -0.001
# A0A192B1T2_9HIV1_Haddox_2018                           0.515   0.456
# A0A1I9GEU1_NEIME_Kennouche_2019                        0.077   0.040
# A0A247D711_LISMN_Stadelmann_2021                       0.320   0.087
# A0A2Z5U3Z0_9INFA_Doud_2016                             0.496   0.124
#
#                                   ESM-1v (single)  ESM-1v (ensemble)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019            -0.048              0.015
# A0A192B1T2_9HIV1_Haddox_2018                0.492              0.516
# A0A1I9GEU1_NEIME_Kennouche_2019             0.068              0.068
# A0A247D711_LISMN_Stadelmann_2021            0.088              0.093
# A0A2Z5U3Z0_9INFA_Doud_2016                  0.516              0.550
#
#                                   ESM2 (8M)  ESM2 (35M)  ESM2 (150M)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019      -0.073      -0.054       -0.058
# A0A192B1T2_9HIV1_Haddox_2018         -0.003       0.015        0.035
# A0A1I9GEU1_NEIME_Kennouche_2019      -0.037      -0.047       -0.016
# A0A247D711_LISMN_Stadelmann_2021      0.064       0.084        0.097
# A0A2Z5U3Z0_9INFA_Doud_2016           -0.004       0.013        0.064
#
#                                   ESM2 (650M)  ESM2 (3B)  ESM2 (15B)  Wavenet  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019         0.213      0.363       0.375    0.216
# A0A192B1T2_9HIV1_Haddox_2018            0.080      0.132       0.164    0.465
# A0A1I9GEU1_NEIME_Kennouche_2019         0.030      0.027       0.025    0.067
# A0A247D711_LISMN_Stadelmann_2021        0.066      0.084       0.084    0.059
# A0A2Z5U3Z0_9INFA_Doud_2016              0.507      0.498       0.501    0.413
#
#                                   RITA S  RITA M  RITA L  RITA XL  Progen2 S  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019    0.361   0.309   0.317    0.305      0.329
# A0A192B1T2_9HIV1_Haddox_2018       0.496   0.507   0.509    0.505      0.497
# A0A1I9GEU1_NEIME_Kennouche_2019   -0.010   0.047   0.071    0.088      0.050
# A0A247D711_LISMN_Stadelmann_2021   0.021   0.015   0.040    0.078     -0.029
# A0A2Z5U3Z0_9INFA_Doud_2016         0.467   0.534   0.520    0.542      0.433
#
#                                   Progen2 M  Progen2 Base  Progen2 L  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019       0.342         0.328      0.312
# A0A192B1T2_9HIV1_Haddox_2018          0.501         0.463      0.490
# A0A1I9GEU1_NEIME_Kennouche_2019       0.088         0.080      0.089
# A0A247D711_LISMN_Stadelmann_2021      0.067         0.010      0.037
# A0A2Z5U3Z0_9INFA_Doud_2016            0.520         0.513      0.494
#
#                                   Progen2 XL  GEMME  VESPA  VESPAl  VespaG  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019        0.293  0.430  0.319   0.296   0.380
# A0A192B1T2_9HIV1_Haddox_2018           0.484  0.496  0.541   0.507   0.299
# A0A1I9GEU1_NEIME_Kennouche_2019        0.095  0.045  0.046   0.036   0.033
# A0A247D711_LISMN_Stadelmann_2021       0.106  0.473  0.337   0.351   0.382
# A0A2Z5U3Z0_9INFA_Doud_2016             0.504  0.538  0.490   0.400   0.563
#
#                                   ProtGPT2  Tranception S no retrieval  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019      0.005                       0.304
# A0A192B1T2_9HIV1_Haddox_2018         0.327                       0.492
# A0A1I9GEU1_NEIME_Kennouche_2019      0.030                       0.036
# A0A247D711_LISMN_Stadelmann_2021     0.093                       0.041
# A0A2Z5U3Z0_9INFA_Doud_2016           0.076                       0.470
#
#                                   Tranception M no retrieval  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                        0.331
# A0A192B1T2_9HIV1_Haddox_2018                           0.483
# A0A1I9GEU1_NEIME_Kennouche_2019                        0.055
# A0A247D711_LISMN_Stadelmann_2021                       0.024
# A0A2Z5U3Z0_9INFA_Doud_2016                             0.525
#
#                                   Tranception L no retrieval  Tranception S  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                        0.272          0.362
# A0A192B1T2_9HIV1_Haddox_2018                           0.514          0.509
# A0A1I9GEU1_NEIME_Kennouche_2019                        0.099          0.031
# A0A247D711_LISMN_Stadelmann_2021                       0.057          0.301
# A0A2Z5U3Z0_9INFA_Doud_2016                             0.523          0.518
#
#                                   Tranception M  Tranception L  TranceptEVE S  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019           0.366          0.351          0.361
# A0A192B1T2_9HIV1_Haddox_2018              0.503          0.513          0.524
# A0A1I9GEU1_NEIME_Kennouche_2019           0.041          0.057          0.058
# A0A247D711_LISMN_Stadelmann_2021          0.292          0.311          0.253
# A0A2Z5U3Z0_9INFA_Doud_2016                0.548          0.537          0.557
#
#                                   TranceptEVE M  TranceptEVE L  CARP (38M)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019           0.358          0.373      -0.060
# A0A192B1T2_9HIV1_Haddox_2018              0.518          0.528       0.422
# A0A1I9GEU1_NEIME_Kennouche_2019           0.061          0.075      -0.055
# A0A247D711_LISMN_Stadelmann_2021          0.242          0.263       0.047
# A0A2Z5U3Z0_9INFA_Doud_2016                0.576          0.573       0.006
#
#                                   CARP (600K)  CARP (640M)  CARP (76M)    MIF  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019        -0.073        0.131      -0.061  0.273
# A0A192B1T2_9HIV1_Haddox_2018           -0.021        0.497       0.429  0.329
# A0A1I9GEU1_NEIME_Kennouche_2019        -0.056        0.039      -0.043  0.051
# A0A247D711_LISMN_Stadelmann_2021        0.002        0.074       0.084  0.418
# A0A2Z5U3Z0_9INFA_Doud_2016              0.000        0.339       0.017  0.430
#
#                                   MIF-ST  ESM-IF1  ProteinMPNN  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019    0.290    0.287        0.129
# A0A192B1T2_9HIV1_Haddox_2018       0.451    0.206        0.136
# A0A1I9GEU1_NEIME_Kennouche_2019    0.055    0.039        0.040
# A0A247D711_LISMN_Stadelmann_2021   0.441    0.476        0.364
# A0A2Z5U3Z0_9INFA_Doud_2016         0.487    0.462        0.174
#
#                                   ProtSSN (k=10, h=512)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.253
# A0A192B1T2_9HIV1_Haddox_2018                      0.202
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.054
# A0A247D711_LISMN_Stadelmann_2021                  0.274
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.489
#
#                                   ProtSSN (k=10, h=768)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.251
# A0A192B1T2_9HIV1_Haddox_2018                      0.230
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.042
# A0A247D711_LISMN_Stadelmann_2021                  0.326
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.474
#
#                                   ProtSSN (k=10, h=1280)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                    0.282
# A0A192B1T2_9HIV1_Haddox_2018                       0.258
# A0A1I9GEU1_NEIME_Kennouche_2019                    0.039
# A0A247D711_LISMN_Stadelmann_2021                   0.314
# A0A2Z5U3Z0_9INFA_Doud_2016                         0.529
#
#                                   ProtSSN (k=20, h=512)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.296
# A0A192B1T2_9HIV1_Haddox_2018                      0.263
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.035
# A0A247D711_LISMN_Stadelmann_2021                  0.344
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.522
#
#                                   ProtSSN (k=20, h=768)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.277
# A0A192B1T2_9HIV1_Haddox_2018                      0.210
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.037
# A0A247D711_LISMN_Stadelmann_2021                  0.313
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.526
#
#                                   ProtSSN (k=20, h=1280)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                    0.269
# A0A192B1T2_9HIV1_Haddox_2018                       0.226
# A0A1I9GEU1_NEIME_Kennouche_2019                    0.052
# A0A247D711_LISMN_Stadelmann_2021                   0.360
# A0A2Z5U3Z0_9INFA_Doud_2016                         0.524
#
#                                   ProtSSN (k=30, h=512)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.263
# A0A192B1T2_9HIV1_Haddox_2018                      0.228
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.039
# A0A247D711_LISMN_Stadelmann_2021                  0.312
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.535
#
#                                   ProtSSN (k=30, h=768)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                   0.269
# A0A192B1T2_9HIV1_Haddox_2018                      0.200
# A0A1I9GEU1_NEIME_Kennouche_2019                   0.058
# A0A247D711_LISMN_Stadelmann_2021                  0.331
# A0A2Z5U3Z0_9INFA_Doud_2016                        0.516
#
#                                   ProtSSN (k=30, h=1280)  ProtSSN (ensemble)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                    0.265               0.278
# A0A192B1T2_9HIV1_Haddox_2018                       0.183               0.239
# A0A1I9GEU1_NEIME_Kennouche_2019                    0.041               0.047
# A0A247D711_LISMN_Stadelmann_2021                   0.265               0.335
# A0A2Z5U3Z0_9INFA_Doud_2016                         0.545               0.537
#
#                                   SaProt (650M)  SaProt (35M)  PoET (200M)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019           0.199         0.116        0.429
# A0A192B1T2_9HIV1_Haddox_2018              0.173         0.084        0.488
# A0A1I9GEU1_NEIME_Kennouche_2019           0.040        -0.005        0.057
# A0A247D711_LISMN_Stadelmann_2021          0.427         0.280        0.458
# A0A2Z5U3Z0_9INFA_Doud_2016                0.199         0.152        0.545
#
#                                   MULAN  ProSST (K=20)  ProSST (K=128)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019   0.071          0.107           0.102
# A0A192B1T2_9HIV1_Haddox_2018      0.051          0.341           0.383
# A0A1I9GEU1_NEIME_Kennouche_2019  -0.016          0.146           0.177
# A0A247D711_LISMN_Stadelmann_2021  0.162          0.450           0.476
# A0A2Z5U3Z0_9INFA_Doud_2016        0.130          0.327           0.324
#
#                                   ProSST (K=512)  ProSST (K=1024)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019            0.113            0.113
# A0A192B1T2_9HIV1_Haddox_2018               0.382            0.404
# A0A1I9GEU1_NEIME_Kennouche_2019            0.199            0.176
# A0A247D711_LISMN_Stadelmann_2021           0.507            0.553
# A0A2Z5U3Z0_9INFA_Doud_2016                 0.356            0.386
#
#                                   ProSST (K=2048)  ProSST (K=4096)  ESCOTT  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019             0.280            0.112   0.471
# A0A192B1T2_9HIV1_Haddox_2018                0.447            0.419   0.522
# A0A1I9GEU1_NEIME_Kennouche_2019             0.076            0.182   0.041
# A0A247D711_LISMN_Stadelmann_2021            0.509            0.544   0.529
# A0A2Z5U3Z0_9INFA_Doud_2016                  0.483            0.374   0.583
#
#                                   VenusREM  RSALOR    S2F  S2F-MSA    S3F  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019      0.387   0.423  0.285    0.402  0.308
# A0A192B1T2_9HIV1_Haddox_2018         0.562   0.532  0.307    0.523  0.365
# A0A1I9GEU1_NEIME_Kennouche_2019      0.070  -0.010  0.043    0.055  0.049
# A0A247D711_LISMN_Stadelmann_2021     0.556   0.481  0.355    0.493  0.400
# A0A2Z5U3Z0_9INFA_Doud_2016           0.557   0.562  0.518    0.590  0.554
#
#                                   S3F-MSA  SiteRM  ESM3 open (1.4B)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019     0.418   0.415             0.277
# A0A192B1T2_9HIV1_Haddox_2018        0.552   0.515             0.257
# A0A1I9GEU1_NEIME_Kennouche_2019     0.058   0.061             0.025
# A0A247D711_LISMN_Stadelmann_2021    0.512   0.449             0.451
# A0A2Z5U3Z0_9INFA_Doud_2016          0.611   0.548             0.406
#
#                                   ESM-C (300M)  ESM-C (600M)  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019         -0.058        -0.048
# A0A192B1T2_9HIV1_Haddox_2018             0.478         0.460
# A0A1I9GEU1_NEIME_Kennouche_2019          0.058         0.051
# A0A247D711_LISMN_Stadelmann_2021         0.096         0.113
# A0A2Z5U3Z0_9INFA_Doud_2016               0.046         0.055
#
#                                   xTrimoPGLM-1B-MLM  xTrimoPGLM-3B-MLM  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019              -0.048              0.366
# A0A192B1T2_9HIV1_Haddox_2018                  0.488              0.521
# A0A1I9GEU1_NEIME_Kennouche_2019               0.042              0.051
# A0A247D711_LISMN_Stadelmann_2021              0.076              0.063
# A0A2Z5U3Z0_9INFA_Doud_2016                    0.095              0.497
#
#                                   xTrimoPGLM-10B-MLM  xTrimoPGLM-1B-CLM  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                0.373              0.332
# A0A192B1T2_9HIV1_Haddox_2018                   0.466              0.476
# A0A1I9GEU1_NEIME_Kennouche_2019                0.053              0.061
# A0A247D711_LISMN_Stadelmann_2021               0.085             -0.028
# A0A2Z5U3Z0_9INFA_Doud_2016                     0.492              0.420
#
#                                   xTrimoPGLM-3B-CLM  xTrimoPGLM-7B-CLM  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019               0.282             -0.024
# A0A192B1T2_9HIV1_Haddox_2018                  0.332              0.024
# A0A1I9GEU1_NEIME_Kennouche_2019               0.020              0.037
# A0A247D711_LISMN_Stadelmann_2021             -0.120              0.004
# A0A2Z5U3Z0_9INFA_Doud_2016                    0.322              0.024
#
#                                   xTrimoPGLM-100B-int4  Progen3 112m  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                  0.303         0.032
# A0A192B1T2_9HIV1_Haddox_2018                     0.334         0.409
# A0A1I9GEU1_NEIME_Kennouche_2019                  0.065        -0.019
# A0A247D711_LISMN_Stadelmann_2021                 0.140         0.047
# A0A2Z5U3Z0_9INFA_Doud_2016                       0.483         0.441
#
#                                   Progen3 219m  Progen3 339m  Progen3 762m  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019          0.191         0.305         0.298
# A0A192B1T2_9HIV1_Haddox_2018             0.482         0.471         0.473
# A0A1I9GEU1_NEIME_Kennouche_2019          0.008         0.043         0.059
# A0A247D711_LISMN_Stadelmann_2021         0.076         0.049         0.054
# A0A2Z5U3Z0_9INFA_Doud_2016               0.466         0.488         0.501
#
#                                   Progen3 1B  Progen3 3B  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019        0.354       0.338
# A0A192B1T2_9HIV1_Haddox_2018           0.487       0.499
# A0A1I9GEU1_NEIME_Kennouche_2019        0.088       0.094
# A0A247D711_LISMN_Stadelmann_2021       0.070       0.107
# A0A2Z5U3Z0_9INFA_Doud_2016             0.534       0.527
#
#                                   AIDO Protein-RAG (16B)  Protriever  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                    0.427       0.477
# A0A192B1T2_9HIV1_Haddox_2018                       0.595       0.504
# A0A1I9GEU1_NEIME_Kennouche_2019                    0.064       0.056
# A0A247D711_LISMN_Stadelmann_2021                   0.524       0.531
# A0A2Z5U3Z0_9INFA_Doud_2016                         0.616       0.527
#
#                                   Number of Mutants     Selection Type  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019                9576  OrganismalFitness
# A0A192B1T2_9HIV1_Haddox_2018                  12577  OrganismalFitness
# A0A1I9GEU1_NEIME_Kennouche_2019                 922           Activity
# A0A247D711_LISMN_Stadelmann_2021               1653           Activity
# A0A2Z5U3Z0_9INFA_Doud_2016                    10715  OrganismalFitness
#
#                                         UniProt ID MSA_Neff_L_category  \
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019    A0A140D2T1_ZIKV              Medium
# A0A192B1T2_9HIV1_Haddox_2018      A0A192B1T2_9HIV1              Medium
# A0A1I9GEU1_NEIME_Kennouche_2019   A0A1I9GEU1_NEIME              Medium
# A0A247D711_LISMN_Stadelmann_2021  A0A247D711_LISMN                 Low
# A0A2Z5U3Z0_9INFA_Doud_2016        A0A2Z5U3Z0_9INFA              Medium
#
#                                        Taxon
# DMS ID
# A0A140D2T1_ZIKV_Sourisseau_2019        Virus
# A0A192B1T2_9HIV1_Haddox_2018           Virus
# A0A1I9GEU1_NEIME_Kennouche_2019   Prokaryote
# A0A247D711_LISMN_Stadelmann_2021  Prokaryote
# A0A2Z5U3Z0_9INFA_Doud_2016             Virus

# %%
# Average dms_substitutions_df over multiple assays with the same DMS id
public_benchmark = dms_substitutions_df.copy()
public_benchmark.index = public_benchmark.index.astype(str)
public_benchmark.drop(["Number of Mutants", "Selection Type", "UniProt ID", "Taxon", "MSA_Neff_L_category"], inplace=True, axis=1, errors='ignore')

public_benchmark = public_benchmark.mean()

# %%
public_benchmark.sort_values(ascending=False).head(n=20)
# Out:
# AIDO Protein-RAG (16B)    0.541926
# VenusREM                  0.535733
# ProSST (K=2048)           0.522530
# S3F-MSA                   0.515382
# ProSST (K=4096)           0.512336
# S2F-MSA                   0.507940
# ProSST (K=1024)           0.503691
# Protriever                0.498930
# ESCOTT                    0.498502
# PoET (200M)               0.489829
# ProSST (K=512)            0.488783
# S3F                       0.488535
# RSALOR                    0.484834
# ProSST (K=128)            0.484820
# ESM3 open (1.4B)          0.482700
# VespaG                    0.481756
# TranceptEVE L             0.474479
# S2F                       0.474364
# GEMME                     0.474253
# TranceptEVE M             0.472848
# dtype: float64

# %%
if not model_paths:
    print("Please set 'model_paths' to your result folders (each containing per-assay CSVs).")
else:
    # Toggle recompute to True to force refresh of cached per-assay Spearman scores
    recompute = False
    ensembles = {
        "AMPLIFY_ensemble": ["AMPLIFY_350M", "AMPLIFY_120M"],
        "SaAMPLIFY_ensemble": ["SaAMPLIFY_350M", "SaAMPLIFY_120M"],
        "SaESM2_ensemble": ["SaESM2_650M", "SaESM2_150M", "SaESM2_35M"],
        "Sa*_ensemble": ["SaAMPLIFY_350M", "SaAMPLIFY_120M", "SaESM2_650M", "SaESM2_150M", "SaESM2_35M"],
        "Thematic_ensemble": ["AMPLIFY_350M", "SaAMPLIFY_350M", "SaESM2_650M", "SaESM2_150M", "SaESM2_35M", "AMPLIFY_120M", "SaAMPLIFY_120M", "AMPLIFY_120M_UR50"],
    }
    wide_df, long_df = evaluate_models(model_paths, dms_substitutions_df, recompute=recompute, ensembles_to_compute=ensembles)
    display(wide_df)
    print(f"Total assays with results: {long_df['assay'].nunique()} across {long_df['model'].nunique()} models")
# Out:
#                     A0A140D2T1_ZIKV_Sourisseau_2019  \
# AMPLIFY_120M                               0.374750
# AMPLIFY_120M_UR50                         -0.067167
# AMPLIFY_120M_base                         -0.100510
# AMPLIFY_350M                               0.404488
# AMPLIFY_350M_base                         -0.049203
# AMPLIFY_C                                 -0.040725
# AMPLIFY_C_base                            -0.055737
# AMPLIFY_ensemble                           0.405983
# ESM-C (300M)                              -0.058000
# ESM-C (600M)                              -0.048000
# ESM2 (150M)                               -0.058000
# ESM2 (15B)                                 0.375000
# ESM2 (35M)                                -0.054000
# ESM2 (3B)                                  0.363000
# ESM2 (650M)                                0.213000
# ESM2 (8M)                                 -0.073000
# ESM3 open (1.4B)                           0.277000
# Sa*_ensemble                               0.391981
# SaAMPLIFY_120M                             0.377311
# SaAMPLIFY_350M                             0.409807
# SaAMPLIFY_ensemble                         0.421336
# SaESM2_150M                               -0.036899
# SaESM2_35M                                -0.067017
# SaESM2_650M                                0.374589
# SaESM2_8M                                 -0.064865
# SaESM2_ensemble                            0.288514
# Thematic_ensemble                          0.400580
#
#                     A0A192B1T2_9HIV1_Haddox_2018  \
# AMPLIFY_120M                            0.477245
# AMPLIFY_120M_UR50                       0.477162
# AMPLIFY_120M_base                       0.471981
# AMPLIFY_350M                            0.461618
# AMPLIFY_350M_base                       0.473598
# AMPLIFY_C                               0.419085
# AMPLIFY_C_base                          0.412841
# AMPLIFY_ensemble                        0.480565
# ESM-C (300M)                            0.478000
# ESM-C (600M)                            0.460000
# ESM2 (150M)                             0.035000
# ESM2 (15B)                              0.164000
# ESM2 (35M)                              0.015000
# ESM2 (3B)                               0.132000
# ESM2 (650M)                             0.080000
# ESM2 (8M)                              -0.003000
# ESM3 open (1.4B)                        0.257000
# Sa*_ensemble                            0.394495
# SaAMPLIFY_120M                          0.465924
# SaAMPLIFY_350M                          0.447787
# SaAMPLIFY_ensemble                      0.476221
# SaESM2_150M                             0.089442
# SaESM2_35M                              0.019021
# SaESM2_650M                             0.280049
# SaESM2_8M                              -0.031826
# SaESM2_ensemble                         0.219350
# Thematic_ensemble                       0.466648
#
#                     A0A1I9GEU1_NEIME_Kennouche_2019  \
# AMPLIFY_120M                               0.053788
# AMPLIFY_120M_UR50                          0.026324
# AMPLIFY_120M_base                          0.047919
# AMPLIFY_350M                               0.022129
# AMPLIFY_350M_base                          0.017905
# AMPLIFY_C                                  0.056941
# AMPLIFY_C_base                             0.067658
# AMPLIFY_ensemble                           0.042156
# ESM-C (300M)                               0.058000
# ESM-C (600M)                               0.051000
# ESM2 (150M)                               -0.016000
# ESM2 (15B)                                 0.025000
# ESM2 (35M)                                -0.047000
# ESM2 (3B)                                  0.027000
# ESM2 (650M)                                0.030000
# ESM2 (8M)                                 -0.037000
# ESM3 open (1.4B)                           0.025000
# Sa*_ensemble                               0.019690
# SaAMPLIFY_120M                             0.022637
# SaAMPLIFY_350M                             0.021191
# SaAMPLIFY_ensemble                         0.021690
# SaESM2_150M                               -0.028343
# SaESM2_35M                                -0.052672
# SaESM2_650M                                0.043782
# SaESM2_8M                                 -0.038777
# SaESM2_ensemble                            0.007620
# Thematic_ensemble                          0.027652
#
#                     A0A247D711_LISMN_Stadelmann_2021  \
# AMPLIFY_120M                                0.116399
# AMPLIFY_120M_UR50                           0.091266
# AMPLIFY_120M_base                           0.086851
# AMPLIFY_350M                                0.090845
# AMPLIFY_350M_base                           0.106917
# AMPLIFY_C                                   0.084975
# AMPLIFY_C_base                              0.105999
# AMPLIFY_ensemble                            0.105925
# ESM-C (300M)                                0.096000
# ESM-C (600M)                                0.113000
# ESM2 (150M)                                 0.097000
# ESM2 (15B)                                  0.084000
# ESM2 (35M)                                  0.084000
# ESM2 (3B)                                   0.084000
# ESM2 (650M)                                 0.066000
# ESM2 (8M)                                   0.064000
# ESM3 open (1.4B)                            0.451000
# Sa*_ensemble                                0.076448
# SaAMPLIFY_120M                              0.106376
# SaAMPLIFY_350M                              0.087525
# SaAMPLIFY_ensemble                          0.098885
# SaESM2_150M                                 0.054020
# SaESM2_35M                                  0.058320
# SaESM2_650M                                 0.067186
# SaESM2_8M                                   0.031545
# SaESM2_ensemble                             0.058700
# Thematic_ensemble                           0.085902
#
#                     A0A2Z5U3Z0_9INFA_Doud_2016  A0A2Z5U3Z0_9INFA_Wu_2014  \
# AMPLIFY_120M                          0.498860                  0.471964
# AMPLIFY_120M_UR50                     0.069026                  0.100316
# AMPLIFY_120M_base                     0.510433                  0.485408
# AMPLIFY_350M                          0.459174                  0.473815
# AMPLIFY_350M_base                     0.469590                  0.481614
# AMPLIFY_C                             0.481367                  0.465837
# AMPLIFY_C_base                        0.481211                  0.462846
# AMPLIFY_ensemble                      0.496064                  0.493983
# ESM-C (300M)                          0.046000                  0.090000
# ESM-C (600M)                          0.055000                  0.086000
# ESM2 (150M)                           0.064000                  0.073000
# ESM2 (15B)                            0.501000                  0.485000
# ESM2 (35M)                            0.013000                  0.073000
# ESM2 (3B)                             0.498000                  0.481000
# ESM2 (650M)                           0.507000                  0.464000
# ESM2 (8M)                            -0.004000                  0.048000
# ESM3 open (1.4B)                      0.406000                  0.350000
# Sa*_ensemble                          0.544085                  0.493007
# SaAMPLIFY_120M                        0.510545                  0.456446
# SaAMPLIFY_350M                        0.511948                  0.481288
# SaAMPLIFY_ensemble                    0.541243                  0.497568
# SaESM2_150M                           0.325434                  0.287181
# SaESM2_35M                            0.136720                  0.134373
# SaESM2_650M                           0.495833                  0.432809
# SaESM2_8M                             0.007871                  0.062514
# SaESM2_ensemble                       0.440686                  0.393197
# Thematic_ensemble                     0.556768                  0.517964
#
#                     A4D664_9INFA_Soh_2019  A4GRB6_PSEAI_Chen_2020  \
# AMPLIFY_120M                     0.263587                0.612264
# AMPLIFY_120M_UR50                0.024874                0.638558
# AMPLIFY_120M_base                0.168127                0.624178
# AMPLIFY_350M                     0.256071                0.712669
# AMPLIFY_350M_base                0.237676                0.720431
# AMPLIFY_C                        0.061064                0.623926
# AMPLIFY_C_base                   0.035205                0.654240
# AMPLIFY_ensemble                 0.274745                0.700526
# ESM-C (300M)                     0.028000                0.680000
# ESM-C (600M)                     0.040000                0.716000
# ESM2 (150M)                      0.027000                0.655000
# ESM2 (15B)                       0.270000                0.627000
# ESM2 (35M)                       0.020000                0.528000
# ESM2 (3B)                        0.211000                0.712000
# ESM2 (650M)                      0.149000                0.738000
# ESM2 (8M)                        0.022000                0.431000
# ESM3 open (1.4B)                 0.271000                0.650000
# Sa*_ensemble                     0.243607                0.719999
# SaAMPLIFY_120M                   0.253649                0.689374
# SaAMPLIFY_350M                   0.241597                0.608165
# SaAMPLIFY_ensemble               0.275133                0.689390
# SaESM2_150M                      0.019584                0.680671
# SaESM2_35M                       0.008221                0.617674
# SaESM2_650M                      0.135845                0.662423
# SaESM2_8M                        0.000564                0.527471
# SaESM2_ensemble                  0.122603                0.710170
# Thematic_ensemble                0.274619                0.736169
#
#                     A4_HUMAN_Seuma_2022  AACC1_PSEAI_Dandage_2018  \
# AMPLIFY_120M                   0.266477                  0.305996
# AMPLIFY_120M_UR50              0.367166                  0.286491
# AMPLIFY_120M_base              0.256687                  0.300904
# AMPLIFY_350M                   0.306875                  0.464644
# AMPLIFY_350M_base              0.140881                  0.466581
# AMPLIFY_C                      0.363550                  0.450534
# AMPLIFY_C_base                 0.294081                  0.462969
# AMPLIFY_ensemble               0.298459                  0.444887
# ESM-C (300M)                   0.517000                  0.519000
# ESM-C (600M)                   0.471000                  0.498000
# ESM2 (150M)                    0.372000                  0.256000
# ESM2 (15B)                     0.352000                  0.518000
# ESM2 (35M)                     0.366000                  0.248000
# ESM2 (3B)                      0.480000                  0.511000
# ESM2 (650M)                    0.431000                  0.490000
# ESM2 (8M)                      0.382000                  0.196000
# ESM3 open (1.4B)               0.377000                  0.520000
# Sa*_ensemble                   0.441743                  0.410234
# SaAMPLIFY_120M                 0.348231                  0.269704
# SaAMPLIFY_350M                 0.356445                  0.423264
# SaAMPLIFY_ensemble             0.372176                  0.406502
# SaESM2_150M                    0.361268                  0.278006
# SaESM2_35M                     0.366173                  0.222072
# SaESM2_650M                    0.441119                  0.454896
# SaESM2_8M                      0.364718                  0.202240
# SaESM2_ensemble                0.406926                  0.393609
# Thematic_ensemble              0.425514                  0.417977
#
#                     ACE2_HUMAN_Chan_2020  ADRB2_HUMAN_Jones_2020  \
# AMPLIFY_120M                    0.139064                0.478961
# AMPLIFY_120M_UR50               0.129503                0.521098
# AMPLIFY_120M_base               0.113850                0.473613
# AMPLIFY_350M                    0.164956                0.452470
# AMPLIFY_350M_base               0.124083                0.468678
# AMPLIFY_C                       0.228428                0.529205
# AMPLIFY_C_base                  0.214081                0.530938
# AMPLIFY_ensemble                0.158613                0.487479
# ESM-C (300M)                    0.233000                0.540000
# ESM-C (600M)                    0.284000                0.549000
# ESM2 (150M)                     0.216000                0.474000
# ESM2 (15B)                      0.178000                0.515000
# ESM2 (35M)                      0.062000                0.444000
# ESM2 (3B)                       0.175000                0.505000
# ESM2 (650M)                     0.225000                0.493000
# ESM2 (8M)                      -0.053000                0.408000
# ESM3 open (1.4B)                0.334000                0.497000
# Sa*_ensemble                    0.247558                0.552505
# SaAMPLIFY_120M                  0.186786                0.511183
# SaAMPLIFY_350M                  0.206030                0.493423
# SaAMPLIFY_ensemble              0.217636                0.518632
# SaESM2_150M                     0.199526                0.520364
# SaESM2_35M                      0.120866                0.480162
# SaESM2_650M                     0.224221                0.523395
# SaESM2_8M                      -0.017551                0.433851
# SaESM2_ensemble                 0.226573                0.533647
# Thematic_ensemble               0.232454                0.549880
#
#                     AICDA_HUMAN_Gajula_2014_3cycles  \
# AMPLIFY_120M                               0.429642
# AMPLIFY_120M_UR50                          0.263671
# AMPLIFY_120M_base                          0.425843
# AMPLIFY_350M                               0.295239
# AMPLIFY_350M_base                          0.248336
# AMPLIFY_C                                  0.237983
# AMPLIFY_C_base                             0.388605
# AMPLIFY_ensemble                           0.418548
# ESM-C (300M)                               0.288000
# ESM-C (600M)                               0.278000
# ESM2 (150M)                                0.196000
# ESM2 (15B)                                 0.262000
# ESM2 (35M)                                -0.264000
# ESM2 (3B)                                  0.347000
# ESM2 (650M)                                0.328000
# ESM2 (8M)                                 -0.245000
# ESM3 open (1.4B)                           0.333000
# Sa*_ensemble                               0.378424
# SaAMPLIFY_120M                             0.461131
# SaAMPLIFY_350M                             0.326274
# SaAMPLIFY_ensemble                         0.465539
# SaESM2_150M                                0.189039
# SaESM2_35M                                -0.154650
# SaESM2_650M                                0.241783
# SaESM2_8M                                 -0.174762
# SaESM2_ensemble                            0.184264
# Thematic_ensemble                          0.417748
#
#                     AMFR_HUMAN_Tsuboyama_2023_4G3O  AMIE_PSEAE_Wrenbeck_2017  \
# AMPLIFY_120M                             -0.145149                  0.574777
# AMPLIFY_120M_UR50                         0.280573                  0.438889
# AMPLIFY_120M_base                        -0.195094                  0.574750
# AMPLIFY_350M                             -0.022961                  0.548469
# AMPLIFY_350M_base                        -0.084488                  0.567662
# AMPLIFY_C                                 0.289168                  0.629144
# AMPLIFY_C_base                            0.470469                  0.620135
# AMPLIFY_ensemble                         -0.074336                  0.596730
# ESM-C (300M)                              0.364000                  0.455000
# ESM-C (600M)                              0.262000                  0.502000
# ESM2 (150M)                               0.321000                  0.428000
# ESM2 (15B)                                0.260000                  0.613000
# ESM2 (35M)                                0.286000                  0.408000
# ESM2 (3B)                                 0.297000                  0.674000
# ESM2 (650M)                               0.261000                  0.557000
# ESM2 (8M)                                -0.209000                  0.326000
# ESM3 open (1.4B)                          0.290000                  0.473000
# Sa*_ensemble                              0.397141                  0.606718
# SaAMPLIFY_120M                           -0.115682                  0.531761
# SaAMPLIFY_350M                            0.458060                  0.572490
# SaAMPLIFY_ensemble                        0.323093                  0.601122
# SaESM2_150M                               0.310555                  0.405603
# SaESM2_35M                                0.260252                  0.386340
# SaESM2_650M                               0.281705                  0.546924
# SaESM2_8M                                -0.181017                  0.317769
# SaESM2_ensemble                           0.351733                  0.498397
# Thematic_ensemble                         0.357978                  0.635949
#
#                     ANCSZ_Hobbs_2022  ARGR_ECOLI_Tsuboyama_2023_1AOY  \
# AMPLIFY_120M                0.450264                        0.259263
# AMPLIFY_120M_UR50           0.582924                        0.491824
# AMPLIFY_120M_base           0.473628                        0.261073
# AMPLIFY_350M                0.488054                        0.483270
# AMPLIFY_350M_base           0.493156                        0.471367
# AMPLIFY_C                   0.527374                        0.414114
# AMPLIFY_C_base              0.525647                        0.448624
# AMPLIFY_ensemble            0.488936                        0.437833
# ESM-C (300M)                0.592000                        0.585000
# ESM-C (600M)                0.561000                        0.534000
# ESM2 (150M)                 0.598000                        0.511000
# ESM2 (15B)                  0.570000                        0.435000
# ESM2 (35M)                  0.592000                        0.297000
# ESM2 (3B)                   0.598000                        0.499000
# ESM2 (650M)                 0.609000                        0.497000
# ESM2 (8M)                   0.535000                        0.332000
# ESM3 open (1.4B)            0.586000                        0.729000
# Sa*_ensemble                0.584802                        0.519029
# SaAMPLIFY_120M              0.442750                        0.398279
# SaAMPLIFY_350M              0.486610                        0.479652
# SaAMPLIFY_ensemble          0.493714                        0.494881
# SaESM2_150M                 0.586626                        0.516748
# SaESM2_35M                  0.575657                        0.404429
# SaESM2_650M                 0.566861                        0.510129
# SaESM2_8M                   0.543701                        0.371654
# SaESM2_ensemble             0.597557                        0.507710
# Thematic_ensemble           0.578744                        0.513552
#
#                     B2L11_HUMAN_Dutta_2010_binding-Mcl-1  \
# AMPLIFY_120M                                    0.137239
# AMPLIFY_120M_UR50                               0.108995
# AMPLIFY_120M_base                               0.225003
# AMPLIFY_350M                                    0.264201
# AMPLIFY_350M_base                               0.243994
# AMPLIFY_C                                       0.136828
# AMPLIFY_C_base                                  0.159639
# AMPLIFY_ensemble                                0.261062
# ESM-C (300M)                                    0.165000
# ESM-C (600M)                                    0.036000
# ESM2 (150M)                                     0.151000
# ESM2 (15B)                                      0.315000
# ESM2 (35M)                                      0.123000
# ESM2 (3B)                                       0.367000
# ESM2 (650M)                                     0.270000
# ESM2 (8M)                                       0.174000
# ESM3 open (1.4B)                                0.316000
# Sa*_ensemble                                    0.352701
# SaAMPLIFY_120M                                  0.123980
# SaAMPLIFY_350M                                  0.270054
# SaAMPLIFY_ensemble                              0.270626
# SaESM2_150M                                     0.104871
# SaESM2_35M                                      0.120225
# SaESM2_650M                                     0.497807
# SaESM2_8M                                       0.242662
# SaESM2_ensemble                                 0.395798
# Thematic_ensemble                               0.321392
#
#                     BBC1_YEAST_Tsuboyama_2023_1TG0  \
# AMPLIFY_120M                              0.388483
# AMPLIFY_120M_UR50                         0.471293
# AMPLIFY_120M_base                         0.354783
# AMPLIFY_350M                              0.452139
# AMPLIFY_350M_base                         0.470173
# AMPLIFY_C                                 0.491521
# AMPLIFY_C_base                            0.466069
# AMPLIFY_ensemble                          0.436603
# ESM-C (300M)                              0.522000
# ESM-C (600M)                              0.509000
# ESM2 (150M)                               0.423000
# ESM2 (15B)                                0.499000
# ESM2 (35M)                                0.421000
# ESM2 (3B)                                 0.458000
# ESM2 (650M)                               0.479000
# ESM2 (8M)                                 0.331000
# ESM3 open (1.4B)                          0.598000
# Sa*_ensemble                              0.448695
# SaAMPLIFY_120M                            0.420050
# SaAMPLIFY_350M                            0.442553
# SaAMPLIFY_ensemble                        0.441938
# SaESM2_150M                               0.383928
# SaESM2_35M                                0.415574
# SaESM2_650M                               0.479562
# SaESM2_8M                                 0.211708
# SaESM2_ensemble                           0.447647
# Thematic_ensemble                         0.456042
#
#                     BCHB_CHLTE_Tsuboyama_2023_2KRU  BLAT_ECOLX_Deng_2012  \
# AMPLIFY_120M                              0.102359              0.303358
# AMPLIFY_120M_UR50                         0.033963              0.485231
# AMPLIFY_120M_base                         0.107785              0.333807
# AMPLIFY_350M                              0.210576              0.248374
# AMPLIFY_350M_base                         0.239010              0.243364
# AMPLIFY_C                                 0.193198              0.532248
# AMPLIFY_C_base                            0.183709              0.549016
# AMPLIFY_ensemble                          0.159418              0.316040
# ESM-C (300M)                              0.450000              0.510000
# ESM-C (600M)                              0.550000              0.527000
# ESM2 (150M)                               0.301000              0.461000
# ESM2 (15B)                                0.421000              0.352000
# ESM2 (35M)                                0.182000              0.354000
# ESM2 (3B)                                 0.521000              0.461000
# ESM2 (650M)                               0.510000              0.528000
# ESM2 (8M)                                 0.166000              0.243000
# ESM3 open (1.4B)                          0.649000              0.538000
# Sa*_ensemble                              0.351366              0.472202
# SaAMPLIFY_120M                            0.139626              0.331899
# SaAMPLIFY_350M                            0.254325              0.323358
# SaAMPLIFY_ensemble                        0.200111              0.363676
# SaESM2_150M                               0.315246              0.476370
# SaESM2_35M                                0.186169              0.420315
# SaESM2_650M                               0.477587              0.404248
# SaESM2_8M                                 0.149776              0.274036
# SaESM2_ensemble                           0.415174              0.484794
# Thematic_ensemble                         0.294271              0.474150
#
#                     BLAT_ECOLX_Firnberg_2014  BLAT_ECOLX_Jacquier_2013  \
# AMPLIFY_120M                        0.337407                  0.356862
# AMPLIFY_120M_UR50                   0.658588                  0.628295
# AMPLIFY_120M_base                   0.366848                  0.396726
# AMPLIFY_350M                        0.294887                  0.316123
# AMPLIFY_350M_base                   0.293732                  0.322197
# AMPLIFY_C                           0.697508                  0.671716
# AMPLIFY_C_base                      0.752886                  0.712326
# AMPLIFY_ensemble                    0.360439                  0.398875
# ESM-C (300M)                        0.708000                  0.677000
# ESM-C (600M)                        0.739000                  0.705000
# ESM2 (150M)                         0.658000                  0.626000
# ESM2 (15B)                          0.424000                  0.503000
# ESM2 (35M)                          0.555000                  0.520000
# ESM2 (3B)                           0.573000                  0.588000
# ESM2 (650M)                         0.737000                  0.704000
# ESM2 (8M)                           0.411000                  0.362000
# ESM3 open (1.4B)                    0.761000                  0.691000
# Sa*_ensemble                        0.613850                  0.612199
# SaAMPLIFY_120M                      0.407379                  0.455771
# SaAMPLIFY_350M                      0.387983                  0.369788
# SaAMPLIFY_ensemble                  0.441522                  0.463381
# SaESM2_150M                         0.620717                  0.599299
# SaESM2_35M                          0.603049                  0.580425
# SaESM2_650M                         0.512741                  0.527022
# SaESM2_8M                           0.449290                  0.396933
# SaESM2_ensemble                     0.651784                  0.634232
# Thematic_ensemble                   0.610464                  0.625404
#
#                     BLAT_ECOLX_Stiffler_2015  BRCA1_HUMAN_Findlay_2018  \
# AMPLIFY_120M                        0.353256                  0.320311
# AMPLIFY_120M_UR50                   0.660813                 -0.091435
# AMPLIFY_120M_base                   0.383979                 -0.081313
# AMPLIFY_350M                        0.307159                  0.443075
# AMPLIFY_350M_base                   0.301373                 -0.056203
# AMPLIFY_C                           0.692816                  0.413958
# AMPLIFY_C_base                      0.748452                  0.266934
# AMPLIFY_ensemble                    0.375730                  0.450200
# ESM-C (300M)                        0.706000                  0.510000
# ESM-C (600M)                        0.735000                  0.541000
# ESM2 (150M)                         0.661000                  0.455000
# ESM2 (15B)                          0.430000                  0.394000
# ESM2 (35M)                          0.557000                  0.392000
# ESM2 (3B)                           0.589000                  0.497000
# ESM2 (650M)                         0.731000                  0.515000
# ESM2 (8M)                           0.399000                  0.134000
# ESM3 open (1.4B)                    0.753000                  0.462000
# Sa*_ensemble                        0.611073                  0.425712
# SaAMPLIFY_120M                      0.404595                  0.341191
# SaAMPLIFY_350M                      0.380508                  0.306476
# SaAMPLIFY_ensemble                  0.435479                  0.362217
# SaESM2_150M                         0.611526                  0.408096
# SaESM2_35M                          0.618343                  0.362900
# SaESM2_650M                         0.503840                  0.375026
# SaESM2_8M                           0.438823                  0.134631
# SaESM2_ensemble                     0.650825                  0.440048
# Thematic_ensemble                   0.613825                  0.451626
#
#                     BRCA2_HUMAN_Erwood_2022_HEK293T  C6KNH7_9INFA_Lee_2018  \
# AMPLIFY_120M                               0.099085               0.285695
# AMPLIFY_120M_UR50                          0.002378               0.008844
# AMPLIFY_120M_base                         -0.022547               0.289576
# AMPLIFY_350M                               0.453112               0.272018
# AMPLIFY_350M_base                         -0.045813               0.273146
# AMPLIFY_C                                  0.482277               0.346348
# AMPLIFY_C_base                            -0.026891               0.381615
# AMPLIFY_ensemble                           0.425491               0.292318
# ESM-C (300M)                               0.437000              -0.010000
# ESM-C (600M)                               0.496000              -0.009000
# ESM2 (150M)                                0.416000              -0.007000
# ESM2 (15B)                                 0.473000               0.426000
# ESM2 (35M)                                 0.103000              -0.022000
# ESM2 (3B)                                  0.464000               0.405000
# ESM2 (650M)                                0.510000               0.483000
# ESM2 (8M)                                  0.088000              -0.014000
# ESM3 open (1.4B)                           0.467000               0.444000
# Sa*_ensemble                               0.462626               0.504064
# SaAMPLIFY_120M                             0.141503               0.395518
# SaAMPLIFY_350M                             0.367761               0.322346
# SaAMPLIFY_ensemble                         0.336370               0.392554
# SaESM2_150M                                0.423994               0.381685
# SaESM2_35M                                 0.217376               0.125893
# SaESM2_650M                                0.529692               0.489786
# SaESM2_8M                                  0.081489              -0.011832
# SaESM2_ensemble                            0.507309               0.479357
# Thematic_ensemble                          0.447590               0.470809
#
#                     CALM1_HUMAN_Weile_2017  CAPSD_AAV2S_Sinai_2021  \
# AMPLIFY_120M                      0.248572                0.226613
# AMPLIFY_120M_UR50                 0.265389                0.220006
# AMPLIFY_120M_base                 0.252527                0.270803
# AMPLIFY_350M                      0.264371                0.500213
# AMPLIFY_350M_base                 0.268194                0.436519
# AMPLIFY_C                         0.241523                0.338539
# AMPLIFY_C_base                    0.247951                0.283516
# AMPLIFY_ensemble                  0.274095                0.495918
# ESM-C (300M)                      0.270000                0.210000
# ESM-C (600M)                      0.252000                0.174000
# ESM2 (150M)                       0.195000                0.203000
# ESM2 (15B)                        0.225000                0.124000
# ESM2 (35M)                        0.199000                0.286000
# ESM2 (3B)                         0.218000                0.183000
# ESM2 (650M)                       0.212000                0.277000
# ESM2 (8M)                         0.161000                0.254000
# ESM3 open (1.4B)                  0.200000                0.372000
# Sa*_ensemble                      0.282119                0.377068
# SaAMPLIFY_120M                    0.245043                0.308746
# SaAMPLIFY_350M                    0.275094                0.286180
# SaAMPLIFY_ensemble                0.277851                0.300639
# SaESM2_150M                       0.244581                0.278150
# SaESM2_35M                        0.214682                0.205395
# SaESM2_650M                       0.256907                0.470305
# SaESM2_8M                         0.172824                0.239832
# SaESM2_ensemble                   0.261345                0.455505
# Thematic_ensemble                 0.294810                0.423217
#
#                     CAR11_HUMAN_Meitlis_2020_gof  \
# AMPLIFY_120M                            0.251303
# AMPLIFY_120M_UR50                       0.354328
# AMPLIFY_120M_base                      -0.001640
# AMPLIFY_350M                            0.238629
# AMPLIFY_350M_base                       0.096059
# AMPLIFY_C                               0.229297
# AMPLIFY_C_base                          0.018614
# AMPLIFY_ensemble                        0.270268
# ESM-C (300M)                            0.281000
# ESM-C (600M)                            0.307000
# ESM2 (150M)                             0.337000
# ESM2 (15B)                              0.357000
# ESM2 (35M)                              0.095000
# ESM2 (3B)                               0.345000
# ESM2 (650M)                             0.326000
# ESM2 (8M)                               0.068000
# ESM3 open (1.4B)                        0.302000
# Sa*_ensemble                            0.353266
# SaAMPLIFY_120M                          0.222914
# SaAMPLIFY_350M                          0.281131
# SaAMPLIFY_ensemble                      0.271466
# SaESM2_150M                             0.369720
# SaESM2_35M                              0.103122
# SaESM2_650M                             0.382146
# SaESM2_8M                               0.066429
# SaESM2_ensemble                         0.386304
# Thematic_ensemble                       0.348649
#
#                     CAR11_HUMAN_Meitlis_2020_lof  \
# AMPLIFY_120M                            0.391158
# AMPLIFY_120M_UR50                       0.512003
# AMPLIFY_120M_base                       0.018422
# AMPLIFY_350M                            0.363703
# AMPLIFY_350M_base                       0.221111
# AMPLIFY_C                               0.335599
# AMPLIFY_C_base                          0.019189
# AMPLIFY_ensemble                        0.414434
# ESM-C (300M)                            0.438000
# ESM-C (600M)                            0.474000
# ESM2 (150M)                             0.462000
# ESM2 (15B)                              0.540000
# ESM2 (35M)                              0.115000
# ESM2 (3B)                               0.533000
# ESM2 (650M)                             0.501000
# ESM2 (8M)                               0.072000
# ESM3 open (1.4B)                        0.427000
# Sa*_ensemble                            0.504072
# SaAMPLIFY_120M                          0.364235
# SaAMPLIFY_350M                          0.375962
# SaAMPLIFY_ensemble                      0.403994
# SaESM2_150M                             0.473217
# SaESM2_35M                              0.142734
# SaESM2_650M                             0.555854
# SaESM2_8M                               0.086004
# SaESM2_ensemble                         0.536774
# Thematic_ensemble                       0.506748
#
#                     CAS9_STRP1_Spencer_2017_positive  \
# AMPLIFY_120M                                0.116951
# AMPLIFY_120M_UR50                           0.101302
# AMPLIFY_120M_base                           0.019512
# AMPLIFY_350M                                0.181561
# AMPLIFY_350M_base                           0.111022
# AMPLIFY_C                                   0.182770
# AMPLIFY_C_base                              0.126488
# AMPLIFY_ensemble                            0.177064
# ESM-C (300M)                                0.165000
# ESM-C (600M)                                0.175000
# ESM2 (150M)                                 0.154000
# ESM2 (15B)                                  0.194000
# ESM2 (35M)                                  0.090000
# ESM2 (3B)                                   0.188000
# ESM2 (650M)                                 0.182000
# ESM2 (8M)                                   0.063000
# ESM3 open (1.4B)                            0.141000
# Sa*_ensemble                                0.187841
# SaAMPLIFY_120M                              0.124589
# SaAMPLIFY_350M                              0.153326
# SaAMPLIFY_ensemble                          0.164479
# SaESM2_150M                                 0.156437
# SaESM2_35M                                  0.087167
# SaESM2_650M                                 0.134362
# SaESM2_8M                                   0.050217
# SaESM2_ensemble                             0.160515
# Thematic_ensemble                           0.191587
#
#                     CASP3_HUMAN_Roychowdhury_2020  \
# AMPLIFY_120M                             0.584375
# AMPLIFY_120M_UR50                        0.597443
# AMPLIFY_120M_base                        0.574653
# AMPLIFY_350M                             0.588567
# AMPLIFY_350M_base                        0.600243
# AMPLIFY_C                                0.622585
# AMPLIFY_C_base                           0.635282
# AMPLIFY_ensemble                         0.612577
# ESM-C (300M)                             0.659000
# ESM-C (600M)                             0.661000
# ESM2 (150M)                              0.639000
# ESM2 (15B)                               0.514000
# ESM2 (35M)                               0.574000
# ESM2 (3B)                                0.554000
# ESM2 (650M)                              0.638000
# ESM2 (8M)                                0.264000
# ESM3 open (1.4B)                         0.573000
# Sa*_ensemble                             0.543772
# SaAMPLIFY_120M                           0.446511
# SaAMPLIFY_350M                           0.414191
# SaAMPLIFY_ensemble                       0.466224
# SaESM2_150M                              0.518957
# SaESM2_35M                               0.514626
# SaESM2_650M                              0.435047
# SaESM2_8M                                0.239178
# SaESM2_ensemble                          0.560431
# Thematic_ensemble                        0.602602
#
#                     CASP7_HUMAN_Roychowdhury_2020  \
# AMPLIFY_120M                             0.593865
# AMPLIFY_120M_UR50                        0.626103
# AMPLIFY_120M_base                        0.589646
# AMPLIFY_350M                             0.590813
# AMPLIFY_350M_base                        0.582481
# AMPLIFY_C                                0.627248
# AMPLIFY_C_base                           0.641141
# AMPLIFY_ensemble                         0.615655
# ESM-C (300M)                             0.648000
# ESM-C (600M)                             0.659000
# ESM2 (150M)                              0.632000
# ESM2 (15B)                               0.562000
# ESM2 (35M)                               0.598000
# ESM2 (3B)                                0.572000
# ESM2 (650M)                              0.622000
# ESM2 (8M)                                0.306000
# ESM3 open (1.4B)                         0.626000
# Sa*_ensemble                             0.614524
# SaAMPLIFY_120M                           0.539682
# SaAMPLIFY_350M                           0.468454
# SaAMPLIFY_ensemble                       0.547830
# SaESM2_150M                              0.605050
# SaESM2_35M                               0.570212
# SaESM2_650M                              0.540446
# SaESM2_8M                                0.316544
# SaESM2_ensemble                          0.621074
# Thematic_ensemble                        0.639081
#
#                     CATR_CHLRE_Tsuboyama_2023_2AMI  \
# AMPLIFY_120M                              0.657183
# AMPLIFY_120M_UR50                         0.646361
# AMPLIFY_120M_base                         0.663562
# AMPLIFY_350M                              0.651873
# AMPLIFY_350M_base                         0.642704
# AMPLIFY_C                                 0.529131
# AMPLIFY_C_base                            0.536929
# AMPLIFY_ensemble                          0.664976
# ESM-C (300M)                              0.637000
# ESM-C (600M)                              0.623000
# ESM2 (150M)                               0.688000
# ESM2 (15B)                                0.644000
# ESM2 (35M)                                0.689000
# ESM2 (3B)                                 0.615000
# ESM2 (650M)                               0.658000
# ESM2 (8M)                                 0.564000
# ESM3 open (1.4B)                          0.676000
# Sa*_ensemble                              0.690288
# SaAMPLIFY_120M                            0.667947
# SaAMPLIFY_350M                            0.664431
# SaAMPLIFY_ensemble                        0.675505
# SaESM2_150M                               0.684602
# SaESM2_35M                                0.668766
# SaESM2_650M                               0.684006
# SaESM2_8M                                 0.627960
# SaESM2_ensemble                           0.692578
# Thematic_ensemble                         0.685056
#
#                     CBPA2_HUMAN_Tsuboyama_2023_1O6X  CBS_HUMAN_Sun_2020  \
# AMPLIFY_120M                               0.595490            0.332934
# AMPLIFY_120M_UR50                          0.758281            0.390295
# AMPLIFY_120M_base                          0.592279            0.341451
# AMPLIFY_350M                               0.752199            0.337291
# AMPLIFY_350M_base                          0.755103            0.340589
# AMPLIFY_C                                  0.720655            0.343793
# AMPLIFY_C_base                             0.654351            0.335313
# AMPLIFY_ensemble                           0.708658            0.349602
# ESM-C (300M)                               0.767000            0.394000
# ESM-C (600M)                               0.730000            0.394000
# ESM2 (150M)                                0.736000            0.335000
# ESM2 (15B)                                 0.718000            0.339000
# ESM2 (35M)                                 0.688000            0.226000
# ESM2 (3B)                                  0.727000            0.329000
# ESM2 (650M)                                0.702000            0.342000
# ESM2 (8M)                                  0.529000            0.085000
# ESM3 open (1.4B)                           0.825000            0.343000
# Sa*_ensemble                               0.782169            0.373296
# SaAMPLIFY_120M                             0.638988            0.298099
# SaAMPLIFY_350M                             0.748064            0.295020
# SaAMPLIFY_ensemble                         0.723043            0.318184
# SaESM2_150M                                0.763303            0.343357
# SaESM2_35M                                 0.641462            0.249110
# SaESM2_650M                                0.778552            0.380990
# SaESM2_8M                                  0.525814            0.094849
# SaESM2_ensemble                            0.795186            0.365548
# Thematic_ensemble                          0.770583            0.384646
#
#                     CBX4_HUMAN_Tsuboyama_2023_2K28  CCDB_ECOLI_Adkar_2012  \
# AMPLIFY_120M                              0.682605               0.517741
# AMPLIFY_120M_UR50                         0.661896               0.407031
# AMPLIFY_120M_base                         0.703753               0.477660
# AMPLIFY_350M                              0.614640               0.265314
# AMPLIFY_350M_base                         0.619434               0.179608
# AMPLIFY_C                                 0.696670               0.402800
# AMPLIFY_C_base                            0.694356               0.396798
# AMPLIFY_ensemble                          0.661151               0.427562
# ESM-C (300M)                              0.627000               0.476000
# ESM-C (600M)                              0.611000               0.472000
# ESM2 (150M)                               0.699000               0.406000
# ESM2 (15B)                                0.606000               0.264000
# ESM2 (35M)                                0.735000              -0.018000
# ESM2 (3B)                                 0.609000               0.463000
# ESM2 (650M)                               0.682000               0.466000
# ESM2 (8M)                                -0.271000              -0.006000
# ESM3 open (1.4B)                          0.663000               0.401000
# Sa*_ensemble                              0.708019               0.429701
# SaAMPLIFY_120M                            0.690771               0.485626
# SaAMPLIFY_350M                            0.621086               0.216202
# SaAMPLIFY_ensemble                        0.669112               0.384789
# SaESM2_150M                               0.716769               0.355618
# SaESM2_35M                                0.714660               0.005815
# SaESM2_650M                               0.631956               0.495413
# SaESM2_8M                                -0.329021              -0.018616
# SaESM2_ensemble                           0.718241               0.425958
# Thematic_ensemble                         0.699844               0.442942
#
#                     CCDB_ECOLI_Tripathi_2016  CCR5_HUMAN_Gill_2023  \
# AMPLIFY_120M                        0.539062              0.273651
# AMPLIFY_120M_UR50                   0.462055              0.353528
# AMPLIFY_120M_base                   0.516293              0.291053
# AMPLIFY_350M                        0.331359              0.275773
# AMPLIFY_350M_base                   0.294011              0.266248
# AMPLIFY_C                           0.480912              0.309469
# AMPLIFY_C_base                      0.477181              0.305240
# AMPLIFY_ensemble                    0.487716              0.294984
# ESM-C (300M)                        0.542000              0.349000
# ESM-C (600M)                        0.535000              0.353000
# ESM2 (150M)                         0.462000              0.362000
# ESM2 (15B)                          0.362000              0.341000
# ESM2 (35M)                         -0.001000              0.358000
# ESM2 (3B)                           0.522000              0.339000
# ESM2 (650M)                         0.511000              0.347000
# ESM2 (8M)                          -0.007000              0.325000
# ESM3 open (1.4B)                    0.448000              0.302000
# Sa*_ensemble                        0.488324              0.368776
# ...
# Thematic_ensemble               0.634534              0.482505
#
#                     UBC9_HUMAN_Weile_2017  UBE4B_HUMAN_Tsuboyama_2023_3L1X  \
# AMPLIFY_120M                     0.394979                         0.437334
# AMPLIFY_120M_UR50                0.456777                         0.449473
# AMPLIFY_120M_base                0.384142                         0.418117
# AMPLIFY_350M                     0.373831                         0.463748
# AMPLIFY_350M_base                0.355065                         0.453227
# AMPLIFY_C                        0.514673                         0.454107
# AMPLIFY_C_base                   0.487057                         0.465193
# AMPLIFY_ensemble                 0.411535                         0.457031
# ESM-C (300M)                     0.499000                         0.488000
# ESM-C (600M)                     0.493000                         0.511000
# ESM2 (150M)                      0.403000                         0.490000
# ESM2 (15B)                       0.538000                         0.477000
# ESM2 (35M)                       0.004000                         0.420000
# ESM2 (3B)                        0.518000                         0.467000
# ESM2 (650M)                      0.473000                         0.460000
# ESM2 (8M)                        0.001000                         0.347000
# ESM3 open (1.4B)                 0.483000                         0.558000
# Sa*_ensemble                     0.478482                         0.471873
# SaAMPLIFY_120M                   0.344310                         0.434971
# SaAMPLIFY_350M                   0.297581                         0.407338
# SaAMPLIFY_ensemble               0.356709                         0.431362
# SaESM2_150M                      0.438870                         0.501102
# SaESM2_35M                       0.074086                         0.444943
# SaESM2_650M                      0.495734                         0.467707
# SaESM2_8M                        0.007866                         0.353238
# SaESM2_ensemble                  0.494834                         0.487287
# Thematic_ensemble                0.490389                         0.471202
#
#                     UBE4B_MOUSE_Starita_2013  UBR5_HUMAN_Tsuboyama_2023_1I2T  \
# AMPLIFY_120M                        0.364027                        0.230721
# AMPLIFY_120M_UR50                   0.437615                        0.385658
# AMPLIFY_120M_base                   0.186142                        0.220366
# AMPLIFY_350M                        0.313712                        0.473472
# AMPLIFY_350M_base                   0.382601                        0.509108
# AMPLIFY_C                           0.352768                        0.547068
# AMPLIFY_C_base                      0.429176                        0.509538
# AMPLIFY_ensemble                    0.370292                        0.407866
# ESM-C (300M)                        0.458000                        0.565000
# ESM-C (600M)                        0.460000                        0.584000
# ESM2 (150M)                         0.459000                        0.158000
# ESM2 (15B)                          0.349000                        0.601000
# ESM2 (35M)                          0.463000                        0.226000
# ESM2 (3B)                           0.351000                        0.591000
# ESM2 (650M)                         0.459000                        0.197000
# ESM2 (8M)                           0.399000                        0.226000
# ESM3 open (1.4B)                    0.386000                        0.719000
# Sa*_ensemble                        0.468456                        0.563309
# SaAMPLIFY_120M                      0.394881                        0.351155
# SaAMPLIFY_350M                      0.319669                        0.577810
# SaAMPLIFY_ensemble                  0.392606                        0.554032
# SaESM2_150M                         0.444299                        0.446272
# SaESM2_35M                          0.463464                        0.388795
# SaESM2_650M                         0.440477                        0.532591
# SaESM2_8M                           0.275101                        0.315368
# SaESM2_ensemble                     0.486430                        0.544175
# Thematic_ensemble                   0.462119                        0.536137
#
#                     VG08_BPP22_Tsuboyama_2023_2GP8  \
# AMPLIFY_120M                              0.537961
# AMPLIFY_120M_UR50                         0.624215
# AMPLIFY_120M_base                         0.537707
# AMPLIFY_350M                              0.506579
# AMPLIFY_350M_base                         0.463566
# AMPLIFY_C                                 0.602962
# AMPLIFY_C_base                            0.660150
# AMPLIFY_ensemble                          0.531401
# ESM-C (300M)                              0.560000
# ESM-C (600M)                              0.576000
# ESM2 (150M)                               0.601000
# ESM2 (15B)                                0.653000
# ESM2 (35M)                                0.514000
# ESM2 (3B)                                 0.611000
# ESM2 (650M)                               0.655000
# ESM2 (8M)                                 0.360000
# ESM3 open (1.4B)                          0.658000
# Sa*_ensemble                              0.652152
# SaAMPLIFY_120M                            0.541264
# SaAMPLIFY_350M                            0.615929
# SaAMPLIFY_ensemble                        0.594745
# SaESM2_150M                               0.645227
# SaESM2_35M                                0.566901
# SaESM2_650M                               0.720536
# SaESM2_8M                                 0.427035
# SaESM2_ensemble                           0.676025
# Thematic_ensemble                         0.627556
#
#                     VILI_CHICK_Tsuboyama_2023_1YU5  \
# AMPLIFY_120M                              0.286484
# AMPLIFY_120M_UR50                         0.647121
# AMPLIFY_120M_base                         0.335642
# AMPLIFY_350M                              0.421034
# AMPLIFY_350M_base                         0.411993
# AMPLIFY_C                                 0.436458
# AMPLIFY_C_base                            0.365001
# AMPLIFY_ensemble                          0.392015
# ESM-C (300M)                              0.659000
# ESM-C (600M)                              0.648000
# ESM2 (150M)                               0.652000
# ESM2 (15B)                                0.478000
# ESM2 (35M)                                0.316000
# ESM2 (3B)                                 0.589000
# ESM2 (650M)                               0.662000
# ESM2 (8M)                                 0.371000
# ESM3 open (1.4B)                          0.781000
# Sa*_ensemble                              0.727507
# SaAMPLIFY_120M                            0.387496
# SaAMPLIFY_350M                            0.581159
# SaAMPLIFY_ensemble                        0.531087
# SaESM2_150M                               0.680700
# SaESM2_35M                                0.359671
# SaESM2_650M                               0.683564
# SaESM2_8M                                 0.365036
# SaESM2_ensemble                           0.707341
# Thematic_ensemble                         0.710679
#
#                     VKOR1_HUMAN_Chiasson_2020_abundance  \
# AMPLIFY_120M                                   0.448528
# AMPLIFY_120M_UR50                              0.504501
# AMPLIFY_120M_base                              0.445199
# AMPLIFY_350M                                   0.444706
# AMPLIFY_350M_base                              0.463895
# AMPLIFY_C                                      0.470669
# AMPLIFY_C_base                                 0.470696
# AMPLIFY_ensemble                               0.463258
# ESM-C (300M)                                   0.446000
# ESM-C (600M)                                   0.460000
# ESM2 (150M)                                    0.500000
# ESM2 (15B)                                     0.472000
# ESM2 (35M)                                     0.443000
# ESM2 (3B)                                      0.484000
# ESM2 (650M)                                    0.493000
# ESM2 (8M)                                      0.251000
# ESM3 open (1.4B)                               0.483000
# Sa*_ensemble                                   0.516823
# SaAMPLIFY_120M                                 0.437701
# SaAMPLIFY_350M                                 0.403853
# SaAMPLIFY_ensemble                             0.439107
# SaESM2_150M                                    0.511159
# SaESM2_35M                                     0.454157
# SaESM2_650M                                    0.493564
# SaESM2_8M                                      0.301506
# SaESM2_ensemble                                0.549709
# Thematic_ensemble                              0.509766
#
#                     VKOR1_HUMAN_Chiasson_2020_activity  \
# AMPLIFY_120M                                  0.377848
# AMPLIFY_120M_UR50                             0.420784
# AMPLIFY_120M_base                             0.387383
# AMPLIFY_350M                                  0.432752
# AMPLIFY_350M_base                             0.422786
# AMPLIFY_C                                     0.429922
# AMPLIFY_C_base                                0.441010
# AMPLIFY_ensemble                              0.425934
# ESM-C (300M)                                  0.414000
# ESM-C (600M)                                  0.435000
# ESM2 (150M)                                   0.369000
# ESM2 (15B)                                    0.445000
# ESM2 (35M)                                    0.298000
# ESM2 (3B)                                     0.446000
# ESM2 (650M)                                   0.430000
# ESM2 (8M)                                     0.016000
# ESM3 open (1.4B)                              0.375000
# Sa*_ensemble                                  0.444987
# SaAMPLIFY_120M                                0.392486
# SaAMPLIFY_350M                                0.408308
# SaAMPLIFY_ensemble                            0.417908
# SaESM2_150M                                   0.395633
# SaESM2_35M                                    0.262506
# SaESM2_650M                                   0.446328
# SaESM2_8M                                     0.031057
# SaESM2_ensemble                               0.434955
# Thematic_ensemble                             0.443236
#
#                     VRPI_BPT7_Tsuboyama_2023_2WNM  \
# AMPLIFY_120M                             0.301152
# AMPLIFY_120M_UR50                        0.537765
# AMPLIFY_120M_base                        0.290532
# AMPLIFY_350M                             0.422530
# AMPLIFY_350M_base                        0.449270
# AMPLIFY_C                                0.506927
# AMPLIFY_C_base                           0.521200
# AMPLIFY_ensemble                         0.373735
# ESM-C (300M)                             0.627000
# ESM-C (600M)                             0.631000
# ESM2 (150M)                              0.507000
# ESM2 (15B)                               0.468000
# ESM2 (35M)                               0.410000
# ESM2 (3B)                                0.612000
# ESM2 (650M)                              0.587000
# ESM2 (8M)                                0.252000
# ESM3 open (1.4B)                         0.668000
# Sa*_ensemble                             0.526694
# SaAMPLIFY_120M                           0.396839
# SaAMPLIFY_350M                           0.420224
# SaAMPLIFY_ensemble                       0.414610
# SaESM2_150M                              0.540987
# SaESM2_35M                               0.438592
# SaESM2_650M                              0.649145
# SaESM2_8M                                0.261726
# SaESM2_ensemble                          0.570043
# Thematic_ensemble                        0.504021
#
#                     YAIA_ECOLI_Tsuboyama_2023_2KVT  YAP1_HUMAN_Araya_2012  \
# AMPLIFY_120M                              0.192911               0.173567
# AMPLIFY_120M_UR50                         0.287190               0.455751
# AMPLIFY_120M_base                         0.245229               0.109118
# AMPLIFY_350M                              0.583257               0.017290
# AMPLIFY_350M_base                         0.460539               0.046559
# AMPLIFY_C                                 0.341498              -0.144767
# AMPLIFY_C_base                            0.390749              -0.190501
# AMPLIFY_ensemble                          0.536753               0.118219
# ESM-C (300M)                              0.229000               0.396000
# ESM-C (600M)                              0.390000               0.298000
# ESM2 (150M)                               0.572000               0.451000
# ESM2 (15B)                                0.684000               0.313000
# ESM2 (35M)                                0.173000               0.457000
# ESM2 (3B)                                 0.684000               0.382000
# ESM2 (650M)                               0.625000               0.466000
# ESM2 (8M)                                -0.107000               0.411000
# ESM3 open (1.4B)                          0.752000               0.439000
# Sa*_ensemble                              0.657342               0.420686
# SaAMPLIFY_120M                            0.235402               0.256731
# SaAMPLIFY_350M                            0.545478               0.081104
# SaAMPLIFY_ensemble                        0.517874               0.200392
# SaESM2_150M                               0.510047               0.482462
# SaESM2_35M                                0.266074               0.466107
# SaESM2_650M                               0.644623               0.473127
# SaESM2_8M                                -0.135086               0.382771
# SaESM2_ensemble                           0.654974               0.492525
# Thematic_ensemble                         0.632615               0.370744
#
#                     YNZC_BACSU_Tsuboyama_2023_2JVD
# AMPLIFY_120M                              0.676071
# AMPLIFY_120M_UR50                         0.647734
# AMPLIFY_120M_base                         0.668601
# AMPLIFY_350M                              0.658580
# AMPLIFY_350M_base                         0.671931
# AMPLIFY_C                                 0.630768
# AMPLIFY_C_base                            0.594085
# AMPLIFY_ensemble                          0.674605
# ESM-C (300M)                              0.589000
# ESM-C (600M)                              0.576000
# ESM2 (150M)                               0.650000
# ESM2 (15B)                                0.630000
# ESM2 (35M)                                0.621000
# ESM2 (3B)                                 0.631000
# ESM2 (650M)                               0.658000
# ESM2 (8M)                                 0.584000
# ESM3 open (1.4B)                          0.671000
# Sa*_ensemble                              0.722781
# SaAMPLIFY_120M                            0.707073
# SaAMPLIFY_350M                            0.708166
# SaAMPLIFY_ensemble                        0.726211
# SaESM2_150M                               0.685396
# SaESM2_35M                                0.599054
# SaESM2_650M                               0.658252
# SaESM2_8M                                 0.611965
# SaESM2_ensemble                           0.700655
# Thematic_ensemble                         0.707575
#
# [27 rows x 217 columns]
# Total assays with results: 217 across 27 models

# %%
# Violin plot comparing models
if 'long_df' in globals() and not long_df.empty:
    # Create custom ordering by family and model size
    ordered_models = []
    for family, models in model_families.items():
        # Filter models that exist in the data and have size info
        family_models = [m for m in models if m in long_df['model'].unique() and m in model_sizes]
        # Sort by model size within family
        family_models.sort(key=lambda x: model_sizes[x])
        ordered_models.extend(family_models)
    # Add the ensemble models at the end
    for ensemble in ensembles.keys():
        if ensemble in long_df['model'].unique():
            ordered_models.append(ensemble)
    
    # Reorder the dataframe
    long_df_ordered = long_df[long_df['model'].isin(ordered_models)].copy()
    long_df_ordered['model'] = pd.Categorical(long_df_ordered['model'], categories=ordered_models, ordered=True)
    
    plt.figure(figsize=(4 + 0.5*len(ordered_models), 8))
    ax = sns.violinplot(data=long_df_ordered, y='spearman', x='model', inner='box', cut=0, palette=colors)
    ax.axhline(0.0, color='k', lw=1, ls='-', alpha=0.5)
    ax.set_ylim(-0.5, 1.1)  # Adjusted based on your data range
    
    # Add mean values as text on the plot
    for i, model in enumerate(ordered_models):
        model_data = long_df_ordered[long_df_ordered['model'] == model]['spearman']
        if not model_data.empty:
            mean_val = model_data.mean()
            ax.text(i, -0.3, f'{mean_val:.4f}', 
                ha='center', va='bottom', fontweight='bold', fontsize=10)
    
    ax.set_title('Per-assay Spearman distribution per model')
    ax.set_ylabel('Spearman correlation')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    print("No data to plot. Fill 'model_paths' and run the evaluation cell above first.")
# Out:
# /tmp/ipykernel_2000232/3656020219.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(data=long_df_ordered, y='spearman', x='model', inner='box', cut=0, palette=colors)

# %%
def sanitize_model_name(name):
    txt = name
    match = re.match(r"^(.*)_(\d+M)$", txt)
    if match:
        model_part = match.group(1)
        size_part = match.group(2)
        return f"{model_part} ({size_part})"
    return name

# %%
# Split violin plots by families: top (ESM + SaESM), bottom-left (AMPLIFY + SaAMPLIFY), bottom-right (ESM-C + ESM3)
if 'long_df' in globals() and not long_df.empty:
    def ordered_models_for_families(families):
        ordered = []
        for fam in families:
            fam_models = [m for m in model_families.get(fam, [])
                          if m in long_df['model'].unique() and m in model_sizes]
            fam_models.sort(key=lambda x: model_sizes[x])
            ordered.extend(fam_models)
        return ordered

    fam_top = ['ESM2', 'SaESM2']
    fam_bl = ['AMPLIFY', 'SaAMPLIFY']
    fam_br = ['ESM-C', 'ESM3']

    ordered_top = ordered_models_for_families(fam_top)
    ordered_bl = ordered_models_for_families(fam_bl)
    ordered_br = ordered_models_for_families(fam_br)

    top_df = long_df[long_df['model'].isin(ordered_top)].copy()
    bl_df = long_df[long_df['model'].isin(ordered_bl)].copy()
    br_df = long_df[long_df['model'].isin(ordered_br)].copy()

    top_df['model'] = pd.Categorical(top_df['model'], categories=ordered_top, ordered=True)
    bl_df['model'] = pd.Categorical(bl_df['model'], categories=ordered_bl, ordered=True)
    br_df['model'] = pd.Categorical(br_df['model'], categories=ordered_br, ordered=True)

    # Figure layout: top spans both columns; bottom has unequal widths (4 vs 3 models)
    fig = plt.figure(figsize=(max(12, 0.8*len(ordered_top)), 16))
    gs = fig.add_gridspec(2, 2, width_ratios=[4, 3], height_ratios=[2, 2], hspace=0.165, wspace=0.15)

    ax_top = fig.add_subplot(gs[0, :])
    ax_bl = fig.add_subplot(gs[1, 0])
    ax_br = fig.add_subplot(gs[1, 1])

    # Common plotting helper
    def draw_violin(ax, data, ordered_models, title, min_ylim=-0.4):
        if data.empty or not ordered_models:
            ax.set_visible(False)
            return
        # Use sanitized model names for x-axis labels
        sanitized_names = [sanitize_model_name(m) for m in ordered_models]
        ax_ = sns.violinplot(
            data=data, y='spearman', x='model', inner='box', cut=0,
            palette=colors, ax=ax
        )
        ax.set_xticklabels(sanitized_names)
        ax.axhline(0.0, color='k', lw=1, ls='-', alpha=0.8)
        ax.set_ylim(min_ylim, 1.1)
        # ax.set_title(title)
        ax.set_xlabel("", fontdict={'fontsize': 1})
        ax.set_ylabel('', fontdict={'fontsize': 1})
        # Blog guidelines styling
        ax.spines[["top", "right", "left"]].set_visible(False)
        ax.spines["bottom"].set_linewidth(2)
        ax.spines["bottom"].set_color("#000000")
        ax.yaxis.grid(True, which="major", linestyle=":")
        ax.set_axisbelow(True)
        ax.tick_params(axis='x', length=0)
        import matplotlib.transforms as mtransforms
        xt = np.array(ax.get_xticks(), dtype=float)
        spacing = float(np.median(np.diff(xt))) if xt.size > 1 else 1.0
        for lbl in ax.get_xticklabels():
            # If the label is modelname_size, transform that to modelname (sizeM)
            lbl.set_rotation(35)
            lbl.set_fontweight('bold')
                # lbl.set_ha('right')
            # lbl.set_ha('right')
            # lbl.set_transform(lbl.get_transform() + mtransforms.ScaledTranslation(spacing/3.0, 0, ax.transData))

        # Add per-model mean
        for i, model in enumerate(ordered_models):
            model_data = data[data['model'] == model]['spearman']
            if not model_data.empty:
                mean_val = model_data.mean()
                ax.text(i, 0.9, f'{mean_val:.4f}', ha='center', va='bottom', fontweight='bold', fontsize=11)

    draw_violin(ax_top, top_df, ordered_top, 'ESM / SaESM', -0.4)
    draw_violin(ax_bl, bl_df, ordered_bl, 'AMPLIFY / SaAMPLIFY', -0.2)
    draw_violin(ax_br, br_df, ordered_br, 'ESM-C / ESM3', -0.2)
    # Shift the y-label to the right for better alignment
    fig.supylabel('Spearman correlation', fontsize=16, x=0.03)

    plt.savefig("violin_proteingym.png", bbox_inches="tight", dpi=300, transparent=True)
    plt.savefig("violin_proteingym.pdf", bbox_inches="tight", transparent=True)
    plt.show()
else:
    print("No data to plot. Fill 'model_paths' and run the evaluation cell above first.")
# Out:
# /tmp/ipykernel_2000232/1896097241.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_ = sns.violinplot(
# /tmp/ipykernel_2000232/1896097241.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sanitized_names)
# /tmp/ipykernel_2000232/1896097241.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_ = sns.violinplot(
# /tmp/ipykernel_2000232/1896097241.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sanitized_names)
# /tmp/ipykernel_2000232/1896097241.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_ = sns.violinplot(
# /tmp/ipykernel_2000232/1896097241.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sanitized_names)

# %%
# Optional: save results
if 'wide_df' in globals() and 'long_df' in globals() and not long_df.empty:
    out_dir = Path.cwd()
    wide_path = out_dir / 'spearman_wide.csv'
    long_path = out_dir / 'spearman_long.csv'
    wide_df.to_csv(wide_path)
    long_df.to_csv(long_path, index=False)
    print(f"Saved: {wide_path}\nSaved: {long_path}")
else:
    print("Nothing to save yet.")
# Out:
# Saved: /home/mila/d/david.heurtel-depeiges/ProteinGym/notebooks/spearman_wide.csv
# Saved: /home/mila/d/david.heurtel-depeiges/ProteinGym/notebooks/spearman_long.csv

# %%
# Plot the average performance vs model size for each model family, using the defined color scheme

if 'long_df' in globals() and not long_df.empty and model_sizes and model_families and 'colors' in globals():
    plt.figure(figsize=(3, 2))
    for family, models in model_families.items():
        fam_models = [m for m in models if m in long_df['model'].unique()]
        if not fam_models:
            continue

        family_data = long_df[long_df['model'].isin(fam_models)]
        avg_per_model = (
            family_data.groupby('model', as_index=False)['spearman']
            .mean()
            .assign(size=lambda d: d['model'].map(model_sizes))
            .dropna(subset=['size'])
            .sort_values('size')
        )
        if avg_per_model.empty:
            continue

        # Line color: use the largest model in the family to represent family color
        line_color_model = avg_per_model.iloc[-1]['model']
        line_color = colors.get(line_color_model, None)

        plt.plot(
            avg_per_model['size'],
            avg_per_model['spearman'],
            linestyle='-.',
            color=line_color,
            label=family,
            markersize=0,
            linewidth=1.5,
            alpha=0.9,
        )

        # Point colors: per-model color from the color scheme
        point_colors = [colors.get(m, '#333333') for m in avg_per_model['model']]
        plt.scatter(
            avg_per_model['size'],
            avg_per_model['spearman'],
            s=28,
            color=point_colors,
            edgecolor='white',
            linewidth=0.5,
            zorder=3,
        )

    plt.xscale('log')
    plt.xlabel('Model Size (M of Params)')
    plt.ylabel('Avg. Spearman Corr.')
    plt.ylim(0.18, 0.5)
    plt.axhline(0.0, color='k', lw=1, ls='--', alpha=0.5)
    plt.grid(True, which="major", ls="--", linewidth=0.3, alpha=0.7)
    plt.legend(title='Family', fontsize=8)
    plt.tight_layout()
    plt.show()

# %%
from matplotlib.lines import Line2D

# Plot the average performance vs model size for each model family, using the defined color scheme
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families and 'colors' in globals():
    
    plt.figure(figsize=(6, 4))
    for family, models in model_families.items():
        fam_models = [m for m in models if m in long_df['model'].unique()]
        if family == "ESM2":
            fam_models = fam_models[:-2]
        if not fam_models:
            continue

        family_data = long_df[long_df['model'].isin(fam_models)]
        avg_per_model = (
            family_data.groupby('model', as_index=False)['spearman']
            .mean()
            .assign(size=lambda d: d['model'].map(model_sizes))
            .dropna(subset=['size'])
            .sort_values('size')
        )
        if avg_per_model.empty:
            continue

        # Line color: use the largest model in the family to represent family color
        line_color_model = avg_per_model.iloc[-1]['model']
        line_color = colors.get(line_color_model, None)

        plt.plot(
            avg_per_model['size'],
            avg_per_model['spearman'],
            linestyle='--',
            color=line_color,
            label=family,
            markersize=0,
            linewidth=1.5,
            alpha=0.9,
        )

        # Point colors: per-model color from the color scheme
        point_colors = [colors.get(m, '#333333') for m in avg_per_model['model']]
        plt.scatter(
            avg_per_model['size'],
            avg_per_model['spearman'],
            s=70,
            color=line_color,
            edgecolor='white',
            linewidth=0.5,
            zorder=3,
        )
    
    ax = plt.gca() # Get current axis
    plt.xscale('log')
    plt.xlabel('Model Size (M of Params)')
    plt.ylabel('Avg. Spearman Corr.')
    plt.ylim(0.18, 0.5)
    plt.axhline(0.0, color='k', lw=1, ls='--', alpha=0.5)
    
    # --- Apply Blog Guidelines ---
    ax.spines[["top", "right", "left"]].set_visible(False)
    ax.spines["bottom"].set_linewidth(2)
    ax.spines["bottom"].set_color("#777777")
    # ax.yaxis.grid(True, which="major", linestyle=":")
    ax.set_axisbelow(True)
    # ax.text(-0.2, 1.1, "d", fontsize=24, fontweight="bold", ha="left", va="top", transform=ax.transAxes)
    # Use the grid from your original code, but ensure it's styled per blog
    ax.grid(True, which="major", ls=":", linewidth=1)
    ax.set_axisbelow(True) # Put grid behind plot
    # Show legend with a big circle as handle for each family
    handles = []
    for family, models in model_families.items():
        fam_models = [m for m in models if m in long_df['model'].unique()]
        if family == "ESM2":
            fam_models = fam_models[:-2]
        if not fam_models:
            continue
        # Use the largest model in the family for color
        largest_model = max(fam_models, key=lambda m: model_sizes[m])
        color = colors.get(largest_model, "#333333")
        handles.append(Line2D([0], [0], marker='o', color='none', markerfacecolor=color, markersize=10, label=family))
    plt.legend(handles=handles, fontsize=10, frameon=False)
    # --- End Guidelines ---

    plt.tight_layout()
        # --- Save the Figure ---
    plt.savefig("scaling_proteingym.png", bbox_inches="tight", dpi=300)
    plt.savefig("scaling_proteingym.pdf", bbox_inches="tight")
    plt.show()

# %%
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families and 'colors' in globals():
    plt.figure(figsize=(6, 4))
    family_lines = {}
    for family, models in model_families.items():
        fam_models = [m for m in models if m in long_df['model'].unique()]
        if family == "ESM2":
            fam_models = fam_models[:-2]
        if not fam_models:
            continue

        family_data = long_df[long_df['model'].isin(fam_models)]
        avg_per_model = (
            family_data.groupby('model', as_index=False)['spearman']
            .mean()
            .assign(size=lambda d: d['model'].map(model_sizes))
            .dropna(subset=['size'])
            .sort_values('size')
        )
        if avg_per_model.empty:
            continue

        line_color_model = avg_per_model.iloc[-1]['model']
        print(line_color_model)
        line_color = colors.get(line_color_model, None)

        line, = plt.plot(
            avg_per_model['size'],
            avg_per_model['spearman'],
            linestyle='--',
            color=line_color,
            label=family,
            markersize=0,
            linewidth=1.5,
            alpha=0.9,
        )
        plt.scatter(
            avg_per_model['size'],
            avg_per_model['spearman'],
            s=70,
            color=line_color,
            edgecolor='white',
            linewidth=0.5,
            zorder=3,
        )
        family_lines[family] = (avg_per_model, line_color)

    ax = plt.gca()
    plt.xscale('log')
    plt.xlabel('Model Size', fontdict={'fontsize': 16,})
    plt.ylabel('Avg. Spearman Corr.', fontdict={'fontsize': 16})
    plt.ylim(0.18, 0.5)
    plt.axhline(0.0, color='k', lw=1, ls='--', alpha=0.5)
    ax.spines[["top", "right", "left"]].set_visible(False)
    ax.spines["bottom"].set_linewidth(2)
    ax.spines["bottom"].set_color("#000000")
    ax.set_axisbelow(True)
    ax.grid(True, which="major", ls=":", linewidth=1, axis='y')
    ax.grid(False, axis='x')
    # Increase font size of ticks
    xticks = [8, 35, 150, 650, 1400]
    ax.set_xticks(xticks)
    xticks_labels = [f"{int(x)}M" if x < 1e3 else f"{(x/1e3):.1f}B" for x in xticks]
    ax.set_xticklabels(xticks_labels, fontsize=12)
    ax.set_axisbelow(True)
    plt.tight_layout()

    custom_labels = True
    if custom_labels:
        # --- Custom family label placement ---
        # ESM3: under its only point
        if "ESM3" in family_lines:
            df, color = family_lines["ESM3"]
            x = df['size'].iloc[0]
            y = df['spearman'].iloc[0]
            ax.annotate("ESM3", (x, y+0.01), xytext=(0, -20), textcoords='offset points',
                        ha='center', va='top', color=color, fontsize=12, fontweight='bold')

        # ESM-C: upper left of its smallest model
        if "ESM-C" in family_lines:
            df, color = family_lines["ESM-C"]
            x = df['size'].iloc[0]
            y = df['spearman'].iloc[0]
            ax.annotate("ESM-C", (x+300, y-0.02), xytext=(-30, 20), textcoords='offset points',
                        ha='right', va='bottom', color=color, fontsize=12, fontweight='bold')

        # ESM2: below the 2nd smallest model
        if "ESM2" in family_lines:
            df, color = family_lines["ESM2"]
            if len(df) > 1:
                x = df['size'].iloc[1]
                y = df['spearman'].iloc[1]
                ax.annotate("ESM2", (x+7, y+0.01), xytext=(0, -20), textcoords='offset points',
                            ha='center', va='top', color=color, fontsize=12, fontweight='bold')

        # SaESM2: above the 2nd smallest model
        if "SaESM2" in family_lines:
            df, color = family_lines["SaESM2"]
            if len(df) > 1:
                x = df['size'].iloc[1]
                y = df['spearman'].iloc[1]
                ax.annotate("SaESM2", (x-10, y-0.02), xytext=(0, 20), textcoords='offset points',
                            ha='center', va='bottom', color=color, fontsize=12, fontweight='bold')

        # AMPLIFY: below the biggest one
        if "AMPLIFY" in family_lines:
            df, color = family_lines["AMPLIFY"]
            x = df['size'].iloc[-1]
            y = df['spearman'].iloc[-1]
            ax.annotate("AMPLIFY", (x-125, y), xytext=(0, -20), textcoords='offset points',
                        ha='center', va='top', color=color, fontsize=12, fontweight='bold')

        # SaAMPLIFY: above the biggest one
        if "SaAMPLIFY" in family_lines:
            df, color = family_lines["SaAMPLIFY"]
            x = df['size'].iloc[-1]
            y = df['spearman'].iloc[-1]
            ax.annotate("SaAMPLIFY", (x+400, y-0.04), xytext=(0, 20), textcoords='offset points',
                        ha='center', va='bottom', color=color, fontsize=12, fontweight='bold')

    plt.savefig("scaling_proteingym.png", bbox_inches="tight", dpi=300)
    plt.savefig("scaling_proteingym.pdf", bbox_inches="tight")
    plt.show()
# Out:
# AMPLIFY_350M
# AMPLIFY_350M_base
# AMPLIFY_C
# AMPLIFY_C_base
# SaAMPLIFY_350M
# ESM2 (650M)
# SaESM2_650M
# ESM-C (600M)
# ESM3 open (1.4B)
# AMPLIFY_120M_UR50

# %%
# ESM2 vs SaESM2: 2x2 plot for sizes 8M, 35M, 150M, 650M
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families:
    sa_family = 'SaESM2'
    regular_family = 'ESM2'
    sa_models = model_families.get(sa_family, [])
    regular_models = model_families.get(regular_family, [])
    
    # Define common sizes for ESM2
    esm2_sizes = [8, 35, 150, 650]

    fig, axes = plt.subplots(2, 2, figsize=(4, 4))
    axes = axes.flatten()
    
    for idx, size in enumerate(esm2_sizes):
        sa_model = next((m for m in sa_models if model_sizes.get(m) == size), None)
        reg_model = next((m for m in regular_models if model_sizes.get(m) == size), None)
        
        if sa_model and reg_model:
            sa_data = long_df[long_df['model'] == sa_model].set_index('assay')
            reg_data = long_df[long_df['model'] == reg_model].set_index('assay')
            merged = sa_data.join(reg_data, lsuffix='_sa', rsuffix='_reg', how='inner')
            
            axes[idx].scatter(
                merged['spearman_reg'],
                merged['spearman_sa'],
                s=30,
                alpha=0.7,
                color=colors.get(sa_model, '#333333')
            )
            axes[idx].plot([-0.5, 1], [-0.5, 1], color='k', lw=1, ls='--', alpha=0.5)
            axes[idx].set_xlim(-0.5, 1)
            axes[idx].set_ylim(-0.5, 1)
            axes[idx].set_xlabel(f'{regular_family} ({size}M) Spearman')
            axes[idx].set_ylabel(f'{sa_family} ({size}M) Spearman')
            axes[idx].set_title(f'{size}M Parameters')
            axes[idx].grid(True, which="major", ls="--", linewidth=0.3, alpha=0.7)
    
    plt.suptitle(f'{regular_family} vs {sa_family} Comparison', fontsize=14, y=0.995)
    plt.tight_layout()
    plt.show()

# AMPLIFY vs SaAMPLIFY: 1x2 plot for sizes 120M, 350M
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families:
    sa_family = 'SaAMPLIFY'
    regular_family = 'AMPLIFY'
    sa_models = model_families.get(sa_family, [])
    regular_models = model_families.get(regular_family, [])
    
    # Define common sizes for AMPLIFY
    amplify_sizes = [120, 350]
    
    fig, axes = plt.subplots(1, 2, figsize=(4, 2))
    
    for idx, size in enumerate(amplify_sizes):
        sa_model = next((m for m in sa_models if model_sizes.get(m) == size), None)
        reg_model = next((m for m in regular_models if model_sizes.get(m) == size), None)
        
        if sa_model and reg_model:
            sa_data = long_df[long_df['model'] == sa_model].set_index('assay')
            reg_data = long_df[long_df['model'] == reg_model].set_index('assay')
            merged = sa_data.join(reg_data, lsuffix='_sa', rsuffix='_reg', how='inner')
            
            axes[idx].scatter(
                merged['spearman_reg'],
                merged['spearman_sa'],
                s=30,
                alpha=0.7,
                color=colors.get(sa_model, '#333333')
            )
            axes[idx].plot([-0.5, 1], [-0.5, 1], color='k', lw=1, ls='--', alpha=0.5)
            axes[idx].set_xlim(-0.5, 1)
            axes[idx].set_ylim(-0.5, 1)
            axes[idx].set_xlabel(f'{regular_family} ({size}M) Spearman')
            axes[idx].set_ylabel(f'{sa_family} ({size}M) Spearman')
            axes[idx].set_title(f'{size}M Parameters')
            axes[idx].grid(True, which="major", ls="--", linewidth=0.3, alpha=0.7)
    
    plt.suptitle(f'{regular_family} vs {sa_family} Comparison', fontsize=14, y=1.02)
    plt.tight_layout()
    plt.show()

# %%
# ESM2 vs SaESM2: 2x2 plot for sizes 8M, 35M, 150M, 650M
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families:
    
    sa_family = 'SaESM2'
    regular_family = 'ESM2'
    sa_models = model_families.get(sa_family, [])
    regular_models = model_families.get(regular_family, [])
    
    # Define common sizes for ESM2
    esm2_sizes = [8, 35, 150, 650]
    
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))
    axes = axes.flatten()
    
    for idx, size in enumerate(esm2_sizes):
        sa_model = next((m for m in sa_models if model_sizes.get(m) == size), None)
        reg_model = next((m for m in regular_models if model_sizes.get(m) == size), None)
        
        ax = axes[idx] # Get current subplot axis
        
        if sa_model and reg_model:
            sa_data = long_df[long_df['model'] == sa_model].set_index('assay')
            reg_data = long_df[long_df['model'] == reg_model].set_index('assay')
            merged = sa_data.join(reg_data, lsuffix='_sa', rsuffix='_reg', how='inner')
            # Color below the line --> smallest model (of the whole family)
            # Colors above the line --> largest model (of the whole family)
            merged['color'] = merged['spearman_sa'] >= merged['spearman_reg']
            
            ax.scatter(
                merged['spearman_reg'],
                merged['spearman_sa'],
                s=30,
                alpha=0.7,
                color=merged['color'].map({True: colors.get('SaESM2_150M'), False: colors.get('ESM2 (150M)', '#333333')})
            )
            ax.plot([-0.5, 1], [-0.5, 1], color='k', lw=1, ls=':', alpha=0.9)
            ax.set_xlim(-0.5, 1)
            ax.set_ylim(-0.5, 1)
            ax.set_xlabel(f'{regular_family} ({size}M) Spearman', fontsize=12)
            ax.set_ylabel(f'{sa_family} ({size}M) Spearman', fontsize=12)
            
            # --- Apply Blog Guidelines ---
            # ax.grid(False, which="major", ls=":")
            ax.grid(False)
            ax.tick_params(axis='both', which='major', labelsize=12)
            ax.set_axisbelow(True) # Put grid behind
            ax.spines[["top", "right"]].set_visible(False) # Remove top/right spines
            ax.spines["bottom"].set_linewidth(1.5) # Thicken bottom spine
            ax.spines["bottom"].set_color("#000000") # Color bottom spine
            ax.spines["left"].set_linewidth(1.5) # Thicken left spine
            ax.spines["left"].set_color("#000000") # Color left spine
            ax.set_aspect('equal', adjustable='box') # Set aspect ratio to equal
            # --- End Guidelines ---
    
    # plt.suptitle(f'{regular_family} / {sa_family} Comparison', fontsize=14, y=0.995)

    plt.savefig("esm2_vs_saesm2_proteingym.png", bbox_inches="tight", dpi=300)
    plt.savefig("esm2_vs_saesm2_proteingym.pdf", bbox_inches="tight")

    plt.tight_layout()
    plt.show()

# %%
# AMPLIFY vs SaAMPLIFY: 1x2 plot for sizes 120M, 350M
if 'long_df' in globals() and not long_df.empty and model_sizes and model_families:
    # Set display quality
    
    sa_family = 'SaAMPLIFY'
    regular_family = 'AMPLIFY'
    sa_models = model_families.get(sa_family, [])
    regular_models = model_families.get(regular_family, [])
    
    # Define common sizes for AMPLIFY
    amplify_sizes = [120, 350]
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    for idx, size in enumerate(amplify_sizes):
        sa_model = next((m for m in sa_models if model_sizes.get(m) == size), None)
        reg_model = next((m for m in regular_models if model_sizes.get(m) == size), None)
        
        ax = axes[idx] # Get current subplot axis

        if sa_model and reg_model:
            sa_data = long_df[long_df['model'] == sa_model].set_index('assay')
            reg_data = long_df[long_df['model'] == reg_model].set_index('assay')
            merged = sa_data.join(reg_data, lsuffix='_sa', rsuffix='_reg', how='inner')

            merged['color'] = merged['spearman_sa'] >= merged['spearman_reg']
            
            ax.scatter(
                merged['spearman_reg'],
                merged['spearman_sa'],
                s=30,
                alpha=0.7,
                color=merged['color'].map({True: colors.get('SaAMPLIFY_120M', '#333333'), False: colors.get('AMPLIFY_120M', '#333333')})
            )
            ax.plot([-0.25, 1], [-0.25, 1], color='k', lw=1, ls=':', alpha=0.9)
            ax.set_xlim(-0.25, 1)
            ax.set_ylim(-0.25, 1)
            ax.set_xlabel(f'{regular_family} ({size}M) Spearman', fontsize=12)
            ax.set_ylabel(f'{sa_family} ({size}M) Spearman', fontsize=12)
            
            # --- Apply Blog Guidelines ---
            # ax.grid(False, which="major", ls=":")
            ax.grid(False)
            ax.tick_params(axis='both', which='major', labelsize=12)
            ax.set_axisbelow(True) # Put grid behind
            ax.spines[["top", "right"]].set_visible(False) # Remove top/right spines
            ax.spines["bottom"].set_linewidth(1.5) # Thicken bottom spine
            ax.spines["bottom"].set_color("#000000") # Color bottom spine
            ax.spines["left"].set_linewidth(1.5) # Thicken left spine
            ax.spines["left"].set_color("#000000") # Color left spine
            ax.set_aspect('equal', adjustable='box') # Set aspect ratio to equal
            # --- End Guidelines ---
    
    # plt.suptitle(f'{regular_family} / {sa_family} Comparison', fontsize=14, y=1.02)

    plt.savefig("amplify_saamplify_comparison_proteingym.png", bbox_inches="tight", dpi=300)
    plt.savefig("amplify_saamplify_comparison_proteingym.pdf", bbox_inches="tight")

    plt.tight_layout()
    plt.show()

# %%
# For each pair of regular vs structure aligned models, please find the top 5 assays 
# where there is the largest difference in positive spearman correlation 
# and the top 5 assays where there is the largest difference in negative spearman correlation

if 'long_df' in globals() and not long_df.empty:
    comparison_pairs = [
        ('ESM2', 'SaESM2'),
        ('AMPLIFY', 'SaAMPLIFY'),
    ]
    
    for regular_family, sa_family in comparison_pairs:
        sa_models = model_families.get(sa_family, [])
        regular_models = model_families.get(regular_family, [])
        
        for size in set(model_sizes.get(m) for m in sa_models).intersection(
            set(model_sizes.get(m) for m in regular_models)
        ):
            sa_model = next((m for m in sa_models if model_sizes.get(m) == size), None)
            reg_model = next((m for m in regular_models if model_sizes.get(m) == size), None)
            
            if sa_model and reg_model:
                sa_data = long_df[long_df['model'] == sa_model].set_index('assay')
                reg_data = long_df[long_df['model'] == reg_model].set_index('assay')
                merged = sa_data.join(reg_data, lsuffix='_sa', rsuffix='_reg', how='inner')
                merged['diff'] = merged['spearman_sa'] - merged['spearman_reg']
                
                top_positive_diff = merged.nlargest(5, 'diff')
                top_negative_diff = merged.nsmallest(5, 'diff')
                
                print(f"\nTop 5 Positive Differences for {regular_family} vs {sa_family} ({size}M):")
                print(top_positive_diff[['spearman_reg', 'spearman_sa', 'diff']])
                
                print(f"\nTop 5 Negative Differences for {regular_family} vs {sa_family} ({size}M):")
                print(top_negative_diff[['spearman_reg', 'spearman_sa', 'diff']])
# Out:
# Top 5 Positive Differences for ESM2 vs SaESM2 (8M):
#                                  spearman_reg  spearman_sa      diff
# assay
# GFP_AEQVI_Sarkisyan_2016                0.078     0.363356  0.285356
# SR43C_ARATH_Tsuboyama_2023_2N88        -0.267    -0.072477  0.194523
# HSP82_YEAST_Mishra_2016                 0.178     0.314148  0.136148
# MBD11_ARATH_Tsuboyama_2023_6ACV        -0.146    -0.015988  0.130012
# OBSCN_HUMAN_Tsuboyama_2023_1V1C         0.392     0.519365  0.127365
#
# Top 5 Negative Differences for ESM2 vs SaESM2 (8M):
#                                 spearman_reg  spearman_sa      diff
# assay
# KCNH2_HUMAN_Kozek_2020                 0.253     0.107518 -0.145482
# PHOT_CHLRE_Chen_2023                   0.768     0.641099 -0.126901
# MYO3_YEAST_Tsuboyama_2023_2BTT         0.171     0.046288 -0.124712
# UBE4B_MOUSE_Starita_2013               0.399     0.275101 -0.123899
# BBC1_YEAST_Tsuboyama_2023_1TG0         0.331     0.211708 -0.119292
#
# Top 5 Positive Differences for ESM2 vs SaESM2 (650M):
#                                 spearman_reg  spearman_sa      diff
# assay
# SPA_STAAU_Tsuboyama_2023_1LP1          0.005     0.574123  0.569123
# GFP_AEQVI_Sarkisyan_2016               0.108     0.603262  0.495262
# NRAM_I33A0_Jiang_2016                  0.161     0.592325  0.431325
# D7PM05_CLYGR_Somermeyer_2022           0.050     0.470240  0.420240
# UBR5_HUMAN_Tsuboyama_2023_1I2T         0.197     0.532591  0.335591
#
# Top 5 Negative Differences for ESM2 vs SaESM2 (650M):
#                                          spearman_reg  spearman_sa      diff
# assay
# RL40A_YEAST_Roscoe_2013                         0.599     0.197514 -0.401486
# RL40A_YEAST_Mavor_2016                          0.518     0.162160 -0.355840
# RL40A_YEAST_Roscoe_2014                         0.530     0.256673 -0.273327
# DYR_ECOLI_Nguyen_2023                           0.544     0.306139 -0.237861
# RASK_HUMAN_Weng_2022_binding-DARPin_K55         0.652     0.419182 -0.232818
#
# Top 5 Positive Differences for ESM2 vs SaESM2 (35M):
#                                      spearman_reg  spearman_sa      diff
# assay
# GFP_AEQVI_Sarkisyan_2016                    0.131     0.616694  0.485694
# D7PM05_CLYGR_Somermeyer_2022                0.053     0.388451  0.335451
# Q53Z42_HUMAN_McShan_2019_expression         0.106     0.419703  0.313703
# NRAM_I33A0_Jiang_2016                      -0.098     0.187065  0.285065
# Q8WTC7_9CNID_Somermeyer_2022               -0.035     0.234083  0.269083
#
# Top 5 Negative Differences for ESM2 vs SaESM2 (35M):
#                                 spearman_reg  spearman_sa      diff
# assay
# MAFG_MOUSE_Tsuboyama_2023_1K1V         0.429     0.220322 -0.208678
# NPC1_HUMAN_Erwood_2022_RPE1            0.394     0.187644 -0.206356
# RASH_HUMAN_Bandaru_2017                0.514     0.413274 -0.100726
# SAV1_MOUSE_Tsuboyama_2023_2YSB         0.496     0.407218 -0.088782
# POLG_HCVJF_Qi_2014                     0.128     0.039968 -0.088032
#
# Top 5 Positive Differences for ESM2 vs SaESM2 (150M):
#                                    spearman_reg  spearman_sa      diff
# assay
# GFP_AEQVI_Sarkisyan_2016                  0.103     0.602111  0.499111
# D7PM05_CLYGR_Somermeyer_2022              0.036     0.475441  0.439441
# NRAM_I33A0_Jiang_2016                     0.005     0.440807  0.435807
# SPIKE_SARS2_Starr_2020_binding           -0.022     0.409784  0.431784
# SPIKE_SARS2_Starr_2020_expression         0.010     0.418515  0.408515
#
# Top 5 Negative Differences for ESM2 vs SaESM2 (150M):
#                                          spearman_reg  spearman_sa      diff
# assay
# RL40A_YEAST_Roscoe_2013                         0.534     0.218780 -0.315220
# RL40A_YEAST_Mavor_2016                          0.482     0.208426 -0.273574
# RL40A_YEAST_Roscoe_2014                         0.529     0.278611 -0.250389
# HECD1_HUMAN_Tsuboyama_2023_3DKM                 0.474     0.311168 -0.162832
# RASK_HUMAN_Weng_2022_binding-DARPin_K55         0.621     0.472371 -0.148629
#
# Top 5 Positive Differences for AMPLIFY vs SaAMPLIFY (120M):
#                                    spearman_reg  spearman_sa      diff
# assay
# GFP_AEQVI_Sarkisyan_2016               0.130438     0.615792  0.485354
# MBD11_ARATH_Tsuboyama_2023_6ACV        0.089213     0.510293  0.421080
# SPIKE_SARS2_Starr_2020_binding        -0.062876     0.307854  0.370730
# SPIKE_SARS2_Starr_2020_expression     -0.008582     0.337410  0.345991
# R1AB_SARS2_Flynn_2022                 -0.040341     0.299235  0.339575
#
# Top 5 Negative Differences for AMPLIFY vs SaAMPLIFY (120M):
#                                spearman_reg  spearman_sa      diff
# assay
# TAT_HV1BR_Fernandes_2016           0.301944     0.097954 -0.203990
# MK01_HUMAN_Brenan_2016             0.122634    -0.022223 -0.144856
# CASP3_HUMAN_Roychowdhury_2020      0.584375     0.446511 -0.137863
# MET_HUMAN_Estevam_2023             0.591540     0.469809 -0.121730
# RL40A_YEAST_Roscoe_2013            0.362612     0.249136 -0.113476
#
# Top 5 Positive Differences for AMPLIFY vs SaAMPLIFY (350M):
#                                 spearman_reg  spearman_sa      diff
# assay
# GFP_AEQVI_Sarkisyan_2016            0.110964     0.616512  0.505548
# AMFR_HUMAN_Tsuboyama_2023_4G3O     -0.022961     0.458060  0.481021
# SPIKE_SARS2_Starr_2020_binding     -0.005717     0.375299  0.381016
# D7PM05_CLYGR_Somermeyer_2022        0.060346     0.422742  0.362397
# SPA_STAAU_Tsuboyama_2023_1LP1      -0.007816     0.349109  0.356925
#
# Top 5 Negative Differences for AMPLIFY vs SaAMPLIFY (350M):
#                                spearman_reg  spearman_sa      diff
# assay
# RL40A_YEAST_Roscoe_2013            0.424253     0.167038 -0.257215
# TRPC_SACS2_Chan_2017               0.619734     0.402045 -0.217689
# CAPSD_AAV2S_Sinai_2021             0.500213     0.286180 -0.214033
# P53_HUMAN_Kotler_2018              0.522178     0.333480 -0.188698
# CASP3_HUMAN_Roychowdhury_2020      0.588567     0.414191 -0.174376

# %%
# I want a list of df of raw scores, for the following models: ESM2, SaESM2, AMPLIFY_350, SaAMPLIFY_350.
# I want 4 lists, each list containing dataframes for each assay, with columns: 'mutation', 'true_score', 'predicted_score'.

def load_raw_scores_for_models(model_paths: Dict[str, str], target_models: List[str]) -> Dict[str, List[pd.DataFrame]]:
    model_dfs: Dict[str, List[pd.DataFrame]] = {model: [] for model in target_models}
    
    for model_name in target_models:
        path = model_paths.get(model_name)
        if path is None or path == "precomputed":
            print(f"Skipping model '{model_name}': no path provided or precomputed.")
            continue
        
        root = Path(str(path).strip())
        if not root.exists():
            print(f"Skipping model '{model_name}': path not found -> {root}")
            continue
        
        for csv_path in iter_assay_csvs(root):
            df = pd.read_csv(csv_path)
            if df.empty:
                print(f"Skipping empty CSV for model '{model_name}' at '{csv_path}'")
                continue

            truth_col = _find_truth_col(df)
            if truth_col is None:
                print(f"Skipping CSV for model '{model_name}' at '{csv_path}': no ground-truth column found.")
                continue
            
            score_cols = _find_model_score_cols(df)
            if not score_cols:
                print(f"Skipping CSV for model '{model_name}' at '{csv_path}': no model score columns found.")
                continue
            
            # Choose the last score column as the predicted score
            predicted_col = score_cols[-1]
            
            # Create a DataFrame with required columns
            result_df = df[[truth_col, predicted_col]].copy()
            result_df.columns = ['true_score', 'predicted_score']
            
            # Add mutation column if available
            result_df['mutant'] = df['mutant']
            model_dfs[model_name].append(result_df)

    return model_dfs

# Example usage:
target_models = ["ESM2 (650M)", "SaESM2_650M", "AMPLIFY_350M", "SaAMPLIFY_350M"]
raw_scores = load_raw_scores_for_models(model_paths, target_models)
# Out:
# Skipping model 'ESM2 (650M)': no path provided or precomputed.

# %%
df = raw_scores['AMPLIFY_350M'][0] # Display the first few rows of the first assay for AMPLIFY_350M

# %%
plt.hist((df['true_score']), bins=30, alpha=0.7)
# plt.hist(df['predicted_score'], bins=30, alpha=0.7)
# Out:
# (array([8.217e+03, 6.190e+02, 2.910e+02, 1.520e+02, 8.200e+01, 4.900e+01,
#         4.300e+01, 2.700e+01, 2.700e+01, 1.500e+01, 1.100e+01, 7.000e+00,
#         6.000e+00, 5.000e+00, 6.000e+00, 1.000e+00, 2.000e+00, 6.000e+00,
#         1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00]),
#  array([2.35396602e-03, 2.83578456e-01, 5.64802947e-01, 8.46027437e-01,
#         1.12725193e+00, 1.40847642e+00, 1.68970091e+00, 1.97092540e+00,
#         2.25214989e+00, 2.53337438e+00, 2.81459887e+00, 3.09582336e+00,
#         3.37704785e+00, 3.65827234e+00, 3.93949683e+00, 4.22072132e+00,
#         4.50194581e+00, 4.78317030e+00, 5.06439479e+00, 5.34561928e+00,
#         5.62684377e+00, 5.90806826e+00, 6.18929275e+00, 6.47051725e+00,
#         6.75174174e+00, 7.03296623e+00, 7.31419072e+00, 7.59541521e+00,
#         7.87663970e+00, 8.15786419e+00, 8.43908868e+00]),
#  <BarContainer object of 30 artists>)

# %%
if 'raw_scores' in globals() and 'AMPLIFY_350M' in raw_scores:
    amplify_dfs = raw_scores['AMPLIFY_350M']
    for assay_df in amplify_dfs:
        # Compute mutation depth
        assay_df['mutation_depth'] = assay_df['mutant'].apply(lambda x: len(x.split(':')) if pd.notna(x) else 0)
        assay_df['normalized_mutation_depth'] = assay_df['mutation_depth'] / assay_df['mutation_depth'].max()
        
        # Normalize true_score and predicted_score ranks
        assay_df['true_score_rank'] = assay_df['true_score'].rank(method='min', pct=True)
        assay_df['predicted_score_rank'] = assay_df['predicted_score'].rank(method='min', pct=True)
        
        assay_df['true_score_rank'] = (assay_df['true_score_rank'] - assay_df['true_score_rank'].min()) / (assay_df['true_score_rank'].max() - assay_df['true_score_rank'].min())
        assay_df['predicted_score_rank'] = (assay_df['predicted_score_rank'] - assay_df['predicted_score_rank'].min()) / (assay_df['predicted_score_rank'].max() - assay_df['predicted_score_rank'].min())

    combined_df = pd.concat([df for df in amplify_dfs if len(df)], ignore_index=True)
else:
    combined_df = pd.DataFrame()

# %%
# I want you to make two scatter plots for AMPLIFY 350M:
# 1) mutation_depth vs true_score_rank , normalized between 0 and 1
# 2) mutation_depth vs predicted_score_rank, normalized between 0 and 1
# Mutation depth can be computed as the number of mutations in the 'mutant' column (assuming it's a string of mutations separated by commas).
# Agregate that for all assays available for AMPLIFY 350M.
if not combined_df.empty:
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].scatter(combined_df['normalized_mutation_depth'], combined_df['true_score_rank'], alpha=0.5, s=1)
    axs[0].set_xlabel('Normalized Mutation Depth')
    axs[0].set_ylabel('Normalized True Score Rank')
    axs[0].set_title('Normalized Mutation Depth vs True Score Rank')
    axs[1].scatter(combined_df['normalized_mutation_depth'], combined_df['predicted_score_rank'], alpha=0.5, s=1)
    axs[1].set_xlabel('Normalized Mutation Depth')
    axs[1].set_ylabel('Normalized Predicted Score Rank')
    axs[1].set_title('Normalized Mutation Depth vs Predicted Score Rank')
    # Add a regression line to each plot
    for ax in axs:
        offsets = ax.collections[0].get_offsets()
        x = offsets[:, 0]
        y = offsets[:, 1]
        mask = ~np.isclose(x, 1.0, atol=1e-12)
        if mask.sum() >= 2:
            z = np.polyfit(x[mask], y[mask], 1)
            p = np.poly1d(z)
            x_line = np.array(ax.get_xlim())
            ax.plot(x_line, p(x_line), color='red', linestyle='--', linewidth=1)
    plt.tight_layout()
    plt.show()
else:
    print("No raw scores available for AMPLIFY_350M to plot.")
